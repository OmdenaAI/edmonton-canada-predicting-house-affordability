# %% [markdown]
# <a href="https://www.kaggle.com/code/aditigulati/income-of-individuals-aditi?scriptVersionId=100732765" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/incomeofindividuals19992020/Income-of-individuals1999-2020.csv
# /kaggle/input/incomeofindividual/Income-of-individuals.csv
# /kaggle/input/housing-affordability-in-canada/Structural-dwellings-household-size.csv
# /kaggle/input/housing-affordability-in-canada/population_dwellings_count.csv
# /kaggle/input/housing-affordability-in-canada/population-by-region-1946-2022.csv
# /kaggle/input/housing-affordability-in-canada/CPI-inflation-by-region-1914-202.csv
# /kaggle/input/housing-affordability-in-canada/HPI 1981-2022 national and provincial.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/ottawa_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saguenay_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/calgary_section1_.csv
# ...

# %%
data=pd.read_csv("../input/incomeofindividual/Income-of-individuals.csv")

# %%
data.head()
# Out:
#                     Geography 4                              Canada 5  \
# 0                     Age group                     16 years and over
# 1                           Sex                            Both sexes
# 2                 Income source  Total income (2020 constant dollars)
# 3                    Statistics                                  2016
# 4  Number of persons  (x 1,000)                               29,166A
#
#                              Canada 5.1                            Canada 5.2  \
# 0                     16 years and over                     16 years and over
# 1                            Both sexes                            Both sexes
# 2  Total income (2020 constant dollars)  Total income (2020 constant dollars)
# 3                                  2017                                  2018
# 4                               29,601A                               30,022A
#
# ...

# %%
data[:10]
# Out:
#                         Geography 4                              Canada 5  \
# 0                         Age group                     16 years and over
# 1                               Sex                            Both sexes
# 2                     Income source  Total income (2020 constant dollars)
# 3                        Statistics                                  2016
# 4      Number of persons  (x 1,000)                               29,166A
# 5     Number with income  (x 1,000)                               28,437A
# 6   Aggregate income  (x 1,000,000)                 2021 constant dollars
# 7  Average income (excluding zeros)                 2022 constant dollars
# 8   Median income (excluding zeros)                 2023 constant dollars
#
#                              Canada 5.1                            Canada 5.2  \
# 0                     16 years and over                     16 years and over
# ...

# %% [markdown]
# |Symbol legend:| |
# |-------------|--|
# |A|data quality: excellent|
# |B|data quality: very good|
# |C| data quality: good|

# %%
import matplotlib.pyplot as plt
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print("duplicated Series values")
print(data.duplicated().sum())
print()
print("About Features : ")
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (9, 71)
#
# unique elements in Features
#
# Geography 4                      9
# Canada 5                         9
# Canada 5.1                       9
# Canada 5.2                       9
# Canada 5.3                       9
#                                 ..
# Vancouver, British Columbia      9
# Vancouver, British Columbia.1    9
# Vancouver, British Columbia.2    9
# Vancouver, British Columbia.3    9
# Vancouver, British Columbia.4    9
# Length: 71, dtype: int64
#
# duplicated Series values
# 0
#
# About Features :
#
# Geography 4                      100.0
# Canada 5                         100.0
# Canada 5.1                       100.0
# Canada 5.2                       100.0
# Canada 5.3                       100.0
#                                  ...
# Vancouver, British Columbia      100.0
# Vancouver, British Columbia.1    100.0
# Vancouver, British Columbia.2    100.0
# Vancouver, British Columbia.3    100.0
# ...

# %% [markdown]
# **Cleaned Data set**

# %%
data.to_csv('Income-of-individuals_clean.csv',index=False) #saved

# %% [markdown]
# **Exploration of DataSet For Later Use**

# %%
df=data.T

# %%
df.iloc[0:1,1:]
# Out:
#                1              2           3                             4  \
# Geography 4  Sex  Income source  Statistics  Number of persons  (x 1,000)
#
#                                          5                                6  \
# Geography 4  Number with income  (x 1,000)  Aggregate income  (x 1,000,000)
#
#                                             7                                8
# Geography 4  Average income (excluding zeros)  Median income (excluding zeros)

# %%
df2 = df.rename(columns={df.columns[0]: 'Geography 4',df.columns[0]: 'Age group',df.columns[1]: 'Sex',df.columns[2]:'Income source',df.columns[3]: 'Statistics',df.columns[4]:'Number of persons (x 1,000)',df.columns[5]: 'Number with income (x 1,000)',df.columns[6]: 'Aggregate income (x 1,000,000)',df.columns[7]: 'Average income (excluding zeros)',df.columns[8]:'Median income (excluding zeros)'})

# %%
df2
# Out:
#                                        Age group         Sex  \
# Geography 4                            Age group         Sex
# Canada 5                       16 years and over  Both sexes
# Canada 5.1                     16 years and over  Both sexes
# Canada 5.2                     16 years and over  Both sexes
# Canada 5.3                     16 years and over  Both sexes
# ...                                          ...         ...
# Vancouver, British Columbia    16 years and over  Both sexes
# Vancouver, British Columbia.1  16 years and over  Both sexes
# Vancouver, British Columbia.2  16 years and over  Both sexes
# Vancouver, British Columbia.3  16 years and over  Both sexes
# Vancouver, British Columbia.4  16 years and over  Both sexes
#
#                                                       Income source  \
# Geography 4                                           Income source
# Canada 5                       Total income (2020 constant dollars)
# ...

# %%
df3=df2.drop(['Geography 4'], axis=0, inplace=True)

# %%
df2
# Out:
#                                        Age group         Sex  \
# Canada 5                       16 years and over  Both sexes
# Canada 5.1                     16 years and over  Both sexes
# Canada 5.2                     16 years and over  Both sexes
# Canada 5.3                     16 years and over  Both sexes
# Canada 5.4                     16 years and over  Both sexes
# ...                                          ...         ...
# Vancouver, British Columbia    16 years and over  Both sexes
# Vancouver, British Columbia.1  16 years and over  Both sexes
# Vancouver, British Columbia.2  16 years and over  Both sexes
# Vancouver, British Columbia.3  16 years and over  Both sexes
# Vancouver, British Columbia.4  16 years and over  Both sexes
#
#                                                       Income source  \
# Canada 5                       Total income (2020 constant dollars)
# Canada 5.1                     Total income (2020 constant dollars)
# ...

# %%
#'Geography 4','Age group','Sex','Income source','Statistics','Number of persons (x 1,000)','Number with income (x 1,000)','Aggregate income (x 1,000,000)','Average income (excluding zeros)','Median income (excluding zeros)'

# %%
df2['Geography 4'] = df2.index
df3=df2.reset_index()
df3.head()
# Out:
#         index          Age group         Sex  \
# 0    Canada 5  16 years and over  Both sexes
# 1  Canada 5.1  16 years and over  Both sexes
# 2  Canada 5.2  16 years and over  Both sexes
# 3  Canada 5.3  16 years and over  Both sexes
# 4  Canada 5.4  16 years and over  Both sexes
#
#                           Income source Statistics  \
# 0  Total income (2020 constant dollars)       2016
# 1  Total income (2020 constant dollars)       2017
# 2  Total income (2020 constant dollars)       2018
# 3  Total income (2020 constant dollars)       2019
# 4  Total income (2020 constant dollars)       2020
#
#   Number of persons (x 1,000) Number with income (x 1,000)  \
# 0                     29,166A                      28,437A
# 1                     29,601A                      28,935A
# 2                     30,022A                      29,475A
# 3                     30,517A                      29,867A
# 4                     30,730A                      30,322A
#
# ...

# %%
df4=df3.drop(['index'], axis = 1)
df4
# Out:
#             Age group         Sex                         Income source  \
# 0   16 years and over  Both sexes  Total income (2020 constant dollars)
# 1   16 years and over  Both sexes  Total income (2020 constant dollars)
# 2   16 years and over  Both sexes  Total income (2020 constant dollars)
# 3   16 years and over  Both sexes  Total income (2020 constant dollars)
# 4   16 years and over  Both sexes  Total income (2020 constant dollars)
# ..                ...         ...                                   ...
# 65  16 years and over  Both sexes  Total income (2020 constant dollars)
# 66  16 years and over  Both sexes  Total income (2020 constant dollars)
# 67  16 years and over  Both sexes  Total income (2020 constant dollars)
# 68  16 years and over  Both sexes  Total income (2020 constant dollars)
# 69  16 years and over  Both sexes  Total income (2020 constant dollars)
#
#    Statistics Number of persons (x 1,000) Number with income (x 1,000)  \
# ...

# %%
import plotly.express as px

# %%
fig = px.scatter(df4, x="Geography 4", y="Number of persons (x 1,000)",color='Statistics')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
fig = px.scatter(df4, x="Geography 4", y="Number with income (x 1,000)",color='Statistics')
fig.show()
# Out:
# <div>                            <div id="31480bfb-04a4-405f-be80-4e4de11a4603" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31480bfb-04a4-405f-be80-4e4de11a4603")) {                    Plotly.newPlot(                        "31480bfb-04a4-405f-be80-4e4de11a4603",                        [{"hovertemplate":"Statistics=2016<br>Geography 4=%{x}<br>Number with income (x 1,000)=%{y}<extra></extra>","legendgroup":"2016","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"2016","orientation":"v","showlegend":true,"x":["Canada 5","Atlantic provinces","Quebec","Ontario","Prairie provinces","British Columbia","Québec, Quebec","Montréal, Quebec","Ottawa-Gatineau, Ontario/Quebec","Toronto, Ontario","Winnipeg, Manitoba","Calgary, Alberta","
# ...

# %%
df4.to_csv('Income-of-individuals_eda.csv',index=False) #saved data ready for eda

# %%
df_1999=pd.read_csv("../input/incomeofindividuals19992020/Income-of-individuals1999-2020.csv")

# %%
df_1999.head()
# Out:
#                                  Unnamed: 0  \
# 0  Income concept 6 (2020 constant dollars)
# 1                      Median market income
# 2                      Median market income
# 3                      Median market income
# 4               Median government transfers
#
#                                          Geography 5 Canada 7 Canada 8  \
# 0                               Economic family type     1999     2000
# 1  Economic families and persons not in an econom...  50,300A  51,400A
# 2                                Economic families 8  70,400A  72,200A
# 3                Persons not in an economic family 9  18,900B  20,000B
# 4  Economic families and persons not in an econom...   4,000B   3,700B
#
#   Canada 9 Canada 10 Canada 11 Canada 12 Canada 13 Canada 14  ...  \
# 0     2001      2002      2003      2004      2005      2006  ...
# 1  51,900A   51,800A   51,800A   52,200A   52,700A   54,100A  ...
# 2  72,100A   71,300A   71,300A   72,700A   73,900A   75,600A  ...
# ...

# %%
df_1999.describe()
# Out:
#                   Unnamed: 0  \
# count                     16
# unique                     6
# top     Median market income
# freq                       3
#
#                                               Geography 5 Canada 7 Canada 8  \
# count                                                  16       16       16
# unique                                                  4       16       16
# top     Economic families and persons not in an econom...     1999     2000
# freq                                                    5        1        1
#
#        Canada 9 Canada 10 Canada 11 Canada 12 Canada 13 Canada 14  ...  \
# count        16        16        16        16        16        16  ...
# unique       16        16        16        16        16        16  ...
# top        2001      2002      2003      2004      2005      2006  ...
# freq          1         1         1         1         1         1  ...
#
#        Vancouver, British Columbia.12 Vancouver, British Columbia.13  \
# ...

# %%
print("Shape of Dataset")
print(df_1999.shape)
print()
print("unique elements in Features")
print()
print(df_1999.nunique())
print()
print("duplicated Series values")
print(df_1999.duplicated().sum())
print()
print("About Features : ")
print()
print(df_1999.count()/df_1999.isna().count()*100)
x=df_1999.count()/df_1999.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (49, 464)
#
# unique elements in Features
#
# Unnamed: 0                         6
# Geography 5                        4
# Canada 7                          16
# Canada 8                          16
# Canada 9                          16
#                                   ..
# Vancouver, British Columbia.17    16
# Vancouver, British Columbia.18    16
# Vancouver, British Columbia.19    16
# Vancouver, British Columbia.20    16
# Vancouver, British Columbia.21    16
# Length: 464, dtype: int64
#
# duplicated Series values
# 32
#
# About Features :
#
# Unnamed: 0                        32.653061
# Geography 5                       32.653061
# Canada 7                          32.653061
# Canada 8                          32.653061
# Canada 9                          32.653061
#                                     ...
# Vancouver, British Columbia.17    32.653061
# Vancouver, British Columbia.18    32.653061
# Vancouver, British Columbia.19    32.653061
# ...

# %%
df_1999.to_csv('Income-of-individuals_1999to2020.csv',index=False)
