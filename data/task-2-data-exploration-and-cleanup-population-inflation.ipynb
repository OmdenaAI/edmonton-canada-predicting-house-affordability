# %% [markdown]
# <a href="https://www.kaggle.com/code/divyamuthukrishnan/task-2-data-exploration-and-cleanup-population?scriptVersionId=99447268" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/structural-type-of-dwelling-household-size-canada/98100040.csv
# /kaggle/input/structural-type-of-dwelling-household-size-canada/98100040_MetaData.csv
# /kaggle/input/Population-dwelling-counts/98100011.csv
# /kaggle/input/Population-dwelling-counts/98100011_MetaData.csv
# /kaggle/input/population-estimates-canadaprovincesterritorries/17100009_MetaData.csv
# /kaggle/input/population-estimates-canadaprovincesterritorries/17100009.csv
# /kaggle/input/housing-affordability-in-canada/Structural-dwellings-household-size.csv
# /kaggle/input/housing-affordability-in-canada/population_dwellings_count.csv
# /kaggle/input/housing-affordability-in-canada/HPI 1981-2022 national and provincial.csv
# /kaggle/input/est-of-the-components-of-demographic-growth-canada/17100008.csv
# /kaggle/input/est-of-the-components-of-demographic-growth-canada/17100008_MetaData.csv
# /kaggle/input/building-construction-price-indexes-canada/18100135.csv
# /kaggle/input/building-construction-price-indexes-canada/18100135_MetaData.csv
# /kaggle/input/consumer-price-index-canada/18100005.csv
# /kaggle/input/consumer-price-index-canada/18100005_MetaData.csv

# %%
import pandas as pd

# %%
# Cons_pr_ind = pd.read_csv('../input/building-construction-price-indexes-canada/18100135.csv')
# Cons_pr_ind.head()

# %% [markdown]
# # Structural type of dwelling and household size: Canada, provinces and territories, census metropolitan areas and census agglomerations with parts

# %%
struct_dwel_df = pd.read_csv('../input/structural-type-of-dwelling-household-size-canada/98100040.csv')
struct_dwel_df.head()
# Out:
#    REF_DATE     GEO           DGUID      Structural type of dwelling (9)  \
# 0      2021  Canada  2021A000011124  Total - Structural type of dwelling
# 1      2021  Canada  2021A000011124                Single-detached house
# 2      2021  Canada  2021A000011124                  Semi-detached house
# 3      2021  Canada  2021A000011124                            Row house
# 4      2021  Canada  2021A000011124        Apartment or flat in a duplex
#
#    Coordinate  Household size (8):Total - Household size[1]  Symbol  \
# 0         1.1                                      14978940     NaN
# 1         1.2                                       7872310     NaN
# 2         1.3                                        746560     NaN
# 3         1.4                                        980105     NaN
# 4         1.5                                        821490     NaN
#
#    Household size (8):1 person[2]  Symbol.1  Household size (8):2 persons[3]  \
# 0                         4396015       NaN                          5124800
# 1                         1437020       NaN                          2901770
# 2                          164040       NaN                           240420
# 3                          243660       NaN                           307010
# 4                          259510       NaN                           253045
#
#    ...  Household size (8):3 persons[4]  Symbol.3  \
# 0  ...                          2194825       NaN
# 1  ...                          1298820       NaN
# 2  ...                           136975       NaN
# 3  ...                           185135       NaN
# 4  ...                           125240       NaN
#
#    Household size (8):4 persons[5]  Symbol.4  \
# 0                          2002455       NaN
# 1                          1364315       NaN
# 2                           125860       NaN
# 3                           150495       NaN
# 4                           104930       NaN
#
#    Household size (8):5 or more persons[6]  Symbol.5  \
# 0                                  1260850       NaN
# 1                                   870380       NaN
# 2                                    79255       NaN
# 3                                    93810       NaN
# 4                                    78770       NaN
#
#    Household size (8):Number of persons in private households[7]  Symbol.6  \
# 0                                           36328475                   NaN
# 1                                           21496250                   NaN
# 2                                            2004855                   NaN
# 3                                            2539830                   NaN
# 4                                            2012905                   NaN
#
#    Household size (8):Average household size[8]  Symbol.7
# 0                                           2.4       NaN
# 1                                           2.7       NaN
# 2                                           2.7       NaN
# 3                                           2.6       NaN
# 4                                           2.5       NaN
#
# [5 rows x 21 columns]

# %%
struct_dwel_df.shape
# Out:
# (1566, 21)

# %%
struct_dwel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 21 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   REF_DATE                                                       1566 non-null   int64
#  1   GEO                                                            1566 non-null   object
#  2   DGUID                                                          1566 non-null   object
#  3   Structural type of dwelling (9)                                1566 non-null   object
#  4   Coordinate                                                     1566 non-null   float64
#  5   Household size (8):Total - Household size[1]                   1566 non-null   int64
#  6   Symbol                                                         0 non-null      float64
#  7   Household size (8):1 person[2]                                 1566 non-null   int64
#  8   Symbol.1                                                       0 non-null      float64
#  9   Household size (8):2 persons[3]                                1566 non-null   int64
#  10  Symbol.2                                                       0 non-null      float64
#  11  Household size (8):3 persons[4]                                1566 non-null   int64
#  12  Symbol.3                                                       0 non-null      float64
#  13  Household size (8):4 persons[5]                                1566 non-null   int64
#  14  Symbol.4                                                       0 non-null      float64
#  15  Household size (8):5 or more persons[6]                        1566 non-null   int64
#  16  Symbol.5                                                       0 non-null      float64
#  17  Household size (8):Number of persons in private households[7]  1566 non-null   int64
#  18  Symbol.6                                                       0 non-null      float64
#  19  Household size (8):Average household size[8]                   1556 non-null   float64
#  20  Symbol.7                                                       59 non-null     object
# dtypes: float64(9), int64(8), object(4)
# memory usage: 257.0+ KB

# %%
# Finding number of unique values in each column

struct_dwel_df.nunique(dropna=True).sort_values()
# Out:
# Symbol.2                                                            0
# Symbol.6                                                            0
# Symbol.5                                                            0
# Symbol.4                                                            0
# Symbol.3                                                            0
# Symbol.1                                                            0
# Symbol                                                              0
# REF_DATE                                                            1
# Symbol.7                                                            2
# Structural type of dwelling (9)                                     9
# Household size (8):Average household size[8]                       30
# DGUID                                                             174
# GEO                                                               174
# Household size (8):5 or more persons[6]                           408
# Household size (8):4 persons[5]                                   483
# Household size (8):3 persons[4]                                   530
# Household size (8):2 persons[3]                                   702
# Household size (8):1 person[2]                                    713
# Household size (8):Total - Household size[1]                      912
# Household size (8):Number of persons in private households[7]    1074
# Coordinate                                                       1566
# dtype: int64

# %% [markdown]
# Total household size should be enough. We dont want granular data for 1 person, 2 person, etc. So we can drop all the columns for 1,2,3,4,and 5+ persons and its corresponding index which has all null values

# %%
# struct_dwel_df.drop(struct_dwel_df.columns[[6,16]], axis=1, inplace=True)
struct_dwel_df.drop(struct_dwel_df.iloc[:, 6:16], inplace = True, axis = 1)

# %%
struct_dwel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 11 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   REF_DATE                                                       1566 non-null   int64
#  1   GEO                                                            1566 non-null   object
#  2   DGUID                                                          1566 non-null   object
#  3   Structural type of dwelling (9)                                1566 non-null   object
#  4   Coordinate                                                     1566 non-null   float64
#  5   Household size (8):Total - Household size[1]                   1566 non-null   int64
#  6   Symbol.5                                                       0 non-null      float64
#  7   Household size (8):Number of persons in private households[7]  1566 non-null   int64
#  8   Symbol.6                                                       0 non-null      float64
#  9   Household size (8):Average household size[8]                   1556 non-null   float64
#  10  Symbol.7                                                       59 non-null     object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 134.7+ KB

# %%
struct_dwel_df.drop(struct_dwel_df.columns[[6, 8, 10]], axis=1, inplace=True)

# %%
struct_dwel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 8 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   REF_DATE                                                       1566 non-null   int64
#  1   GEO                                                            1566 non-null   object
#  2   DGUID                                                          1566 non-null   object
#  3   Structural type of dwelling (9)                                1566 non-null   object
#  4   Coordinate                                                     1566 non-null   float64
#  5   Household size (8):Total - Household size[1]                   1566 non-null   int64
#  6   Household size (8):Number of persons in private households[7]  1566 non-null   int64
#  7   Household size (8):Average household size[8]                   1556 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 98.0+ KB

# %%
#renaming the columns for readability
struct_dwel_df.rename(columns = {'Structural type of dwelling (9)':'Structural type of dwelling', 
                                 'Household size (8):Total - Household size[1]':'Total - Household',
                                 'Household size (8):Number of persons in private households[7]':'Number of persons in private households', 
                                 'Household size (8):Average household size[8]' : 'Average household size'},
                                 inplace = True)

# %%
struct_dwel_df.head()
# Out:
#    REF_DATE     GEO           DGUID          Structural type of dwelling  \
# 0      2021  Canada  2021A000011124  Total - Structural type of dwelling
# 1      2021  Canada  2021A000011124                Single-detached house
# 2      2021  Canada  2021A000011124                  Semi-detached house
# 3      2021  Canada  2021A000011124                            Row house
# 4      2021  Canada  2021A000011124        Apartment or flat in a duplex
#
#    Coordinate  Total - Household  Number of persons in private households  \
# 0         1.1           14978940                                 36328475
# 1         1.2            7872310                                 21496250
# 2         1.3             746560                                  2004855
# 3         1.4             980105                                  2539830
# 4         1.5             821490                                  2012905
#
#    Average household size
# 0                     2.4
# 1                     2.7
# 2                     2.7
# 3                     2.6
# 4                     2.5

# %% [markdown]
# **The above table has Structural type of dwelling and household size: Canada, provinces and territories, census metropolitan areas and census agglomerations with parts**

# %%
struct_dwel_df.to_csv('Structural-dwelling-household-size-edited.csv',index=False)

# %%
df = pd.read_csv('./Structural-dwelling-household-size-edited.csv')
df.head()
# Out:
#    REF_DATE     GEO           DGUID          Structural type of dwelling  \
# 0      2021  Canada  2021A000011124  Total - Structural type of dwelling
# 1      2021  Canada  2021A000011124                Single-detached house
# 2      2021  Canada  2021A000011124                  Semi-detached house
# 3      2021  Canada  2021A000011124                            Row house
# 4      2021  Canada  2021A000011124        Apartment or flat in a duplex
#
#    Coordinate  Total - Household  Number of persons in private households  \
# 0         1.1           14978940                                 36328475
# 1         1.2            7872310                                 21496250
# 2         1.3             746560                                  2004855
# 3         1.4             980105                                  2539830
# 4         1.5             821490                                  2012905
#
#    Average household size
# 0                     2.4
# 1                     2.7
# 2                     2.7
# 3                     2.6
# 4                     2.5

# %%
df.shape
# Out:
# (1566, 8)

# %% [markdown]
# # Population and dwelling counts: Canada and population centres

# %%
population_df = pd.read_csv('../input/Population-dwelling-counts/98100011.csv')
population_df.head()
# Out:
#    REF_DATE                        GEO           DGUID  Coordinate  \
# 0      2021                     Canada  2021A000011124           1
# 1      2021  Newfoundland and Labrador     2021A000210           2
# 2      2021                Bay Roberts   2021S05100046           3
# 3      2021             Bishop's Falls   2021S05100072           4
# 4      2021                  Bonavista   2021S05100082           5
#
#    Population and dwelling counts (7): Population, 2021 [1]  Symbols  \
# 0                                           36991981             NaN
# 1                                             510550             NaN
# 2                                               6897             NaN
# 3                                               3006             NaN
# 4                                               2979             NaN
#
#    Population and dwelling counts (7): Population, 2016 [2] Symbols.1  \
# 0                                           35151728              NaN
# 1                                             519716              NaN
# 2                                               6896                r
# 3                                               3087                r
# 4                                               3140              NaN
#
#    Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]  \
# 0                                                5.2
# 1                                               -1.8
# 2                                                0.0
# 3                                               -2.6
# 4                                               -5.1
#
#    Symbols.2  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#    Population and dwelling counts (7): Total private dwellings, 2021 [4]  \
# 0                                           16284235
# 1                                             269184
# 2                                               3184
# 3                                               1498
# 4                                               1628
#
#    Symbols.3  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#    Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]  \
# 0                                           14978941
# 1                                             223253
# 2                                               2888
# 3                                               1386
# 4                                               1379
#
#    Symbols.4  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#    Population and dwelling counts (7): Land area in square kilometres, 2021 [6]  \
# 0                                         8788702.80
# 1                                          358170.37
# 2                                              16.88
# 3                                               6.89
# 4                                               4.36
#
#    Symbols.5  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#    Population and dwelling counts (7): Population density per square kilometre, 2021 [7]  \
# 0                                                4.2
# 1                                                1.4
# 2                                              408.5
# 3                                              436.1
# 4                                              683.1
#
#    Symbols.6
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 18 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   REF_DATE                                                                                     1048 non-null   int64
#  1   GEO                                                                                          1048 non-null   object
#  2   DGUID                                                                                        1048 non-null   object
#  3   Coordinate                                                                                   1048 non-null   int64
#  4   Population and dwelling counts (7): Population, 2021 [1]                                     1048 non-null   int64
#  5   Symbols                                                                                      0 non-null      float64
#  6   Population and dwelling counts (7): Population, 2016 [2]                                     1048 non-null   int64
#  7   Symbols.1                                                                                    540 non-null    object
#  8   Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]           1048 non-null   float64
#  9   Symbols.2                                                                                    0 non-null      float64
#  10  Population and dwelling counts (7): Total private dwellings, 2021 [4]                        1048 non-null   int64
#  11  Symbols.3                                                                                    0 non-null      float64
#  12  Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]  1048 non-null   int64
#  13  Symbols.4                                                                                    0 non-null      float64
#  14  Population and dwelling counts (7): Land area in square kilometres, 2021 [6]                 1048 non-null   float64
#  15  Symbols.5                                                                                    0 non-null      float64
#  16  Population and dwelling counts (7): Population density per square kilometre, 2021 [7]        1048 non-null   float64
#  17  Symbols.6                                                                                    0 non-null      float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 147.5+ KB

# %% [markdown]
# Remove all the columns with null values (symbols column)

# %%
population_df.drop(population_df.columns[[5, 7, 9, 11, 13, 15, 17]], axis=1, inplace=True)

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 11 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   REF_DATE                                                                                     1048 non-null   int64
#  1   GEO                                                                                          1048 non-null   object
#  2   DGUID                                                                                        1048 non-null   object
#  3   Coordinate                                                                                   1048 non-null   int64
#  4   Population and dwelling counts (7): Population, 2021 [1]                                     1048 non-null   int64
#  5   Population and dwelling counts (7): Population, 2016 [2]                                     1048 non-null   int64
#  6   Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]           1048 non-null   float64
#  7   Population and dwelling counts (7): Total private dwellings, 2021 [4]                        1048 non-null   int64
#  8   Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]  1048 non-null   int64
#  9   Population and dwelling counts (7): Land area in square kilometres, 2021 [6]                 1048 non-null   float64
#  10  Population and dwelling counts (7): Population density per square kilometre, 2021 [7]        1048 non-null   float64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 90.2+ KB

# %%
#renaming the columns for readability
population_df.rename(columns = {'Population and dwelling counts (7): Population, 2021 [1]':'Population,2021', 
                                 'Population and dwelling counts (7): Population, 2016 [2]':'Population,2016',
                                 'Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]':'Population percentage change', 
                                 'Population and dwelling counts (7): Total private dwellings, 2021 [4]' : 'Total private dwellings,2021',
                                 'Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]':'Private dwellings occupied by usual residents, 2021', 
                                 'Population and dwelling counts (7): Land area in square kilometres, 2021 [6]' : 'Land area in square kilometres,2021',
                                 'Population and dwelling counts (7): Population density per square kilometre, 2021 [7]' : 'Population density per square kilometre,2021',
                                    
                                },
                                 inplace = True)

# %%
population_df.head()
# Out:
#    REF_DATE                        GEO           DGUID  Coordinate  \
# 0      2021                     Canada  2021A000011124           1
# 1      2021  Newfoundland and Labrador     2021A000210           2
# 2      2021                Bay Roberts   2021S05100046           3
# 3      2021             Bishop's Falls   2021S05100072           4
# 4      2021                  Bonavista   2021S05100082           5
#
#    Population,2021  Population,2016  Population percentage change  \
# 0         36991981         35151728                           5.2
# 1           510550           519716                          -1.8
# 2             6897             6896                           0.0
# 3             3006             3087                          -2.6
# 4             2979             3140                          -5.1
#
#    Total private dwellings,2021  \
# 0                      16284235
# 1                        269184
# 2                          3184
# 3                          1498
# 4                          1628
#
#    Private dwellings occupied by usual residents, 2021  \
# 0                                           14978941
# 1                                             223253
# 2                                               2888
# 3                                               1386
# 4                                               1379
#
#    Land area in square kilometres,2021  \
# 0                           8788702.80
# 1                            358170.37
# 2                                16.88
# 3                                 6.89
# 4                                 4.36
#
#    Population density per square kilometre,2021
# 0                                           4.2
# 1                                           1.4
# 2                                         408.5
# 3                                         436.1
# 4                                         683.1

# %%
population_df.to_csv('population_df_edited.csv',index=False)

# %%
edited_population_df = pd.read_csv('./population_df_edited.csv')
edited_population_df.head()
# Out:
#    REF_DATE                        GEO           DGUID  Coordinate  \
# 0      2021                     Canada  2021A000011124           1
# 1      2021  Newfoundland and Labrador     2021A000210           2
# 2      2021                Bay Roberts   2021S05100046           3
# 3      2021             Bishop's Falls   2021S05100072           4
# 4      2021                  Bonavista   2021S05100082           5
#
#    Population,2021  Population,2016  Population percentage change  \
# 0         36991981         35151728                           5.2
# 1           510550           519716                          -1.8
# 2             6897             6896                           0.0
# 3             3006             3087                          -2.6
# 4             2979             3140                          -5.1
#
#    Total private dwellings,2021  \
# 0                      16284235
# 1                        269184
# 2                          3184
# 3                          1498
# 4                          1628
#
#    Private dwellings occupied by usual residents, 2021  \
# 0                                           14978941
# 1                                             223253
# 2                                               2888
# 3                                               1386
# 4                                               1379
#
#    Land area in square kilometres,2021  \
# 0                           8788702.80
# 1                            358170.37
# 2                                16.88
# 3                                 6.89
# 4                                 4.36
#
#    Population density per square kilometre,2021
# 0                                           4.2
# 1                                           1.4
# 2                                         408.5
# 3                                         436.1
# 4                                         683.1

# %%
edited_population_df.shape
# Out:
# (1048, 11)

# %% [markdown]
# # Population estimates, canada provinces, quarterly data (year 1946 - 2022)
#
# Note: Postcensal estimates are based on the 2016 Census counts adjusted for census net undercoverage (CNU) (including adjustment for incompletely enumerated Indian reserves (IEIR)) and the components of demographic growth that occurred since that census. Intercensal estimates are produced using counts from two consecutive censuses adjusted for CNU (including IEIR) and postcensal estimates.
#
# The population growth, which is used to calculate population estimates, is comprised of the natural growth (Table 17100059), international migration (Table 17100040) and interprovincial migration (Tables 17100020 and 17100045).

# %%
pop_est_df = pd.read_csv('../input/population-estimates-canadaprovincesterritorries/17100009.csv')
pop_est_df.head()
# Out:
#   REF_DATE     GEO           DGUID      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0  1946-01  Canada  2016A000011124  Persons     249         units          0
# 1  1946-04  Canada  2016A000011124  Persons     249         units          0
# 2  1946-07  Canada  2016A000011124  Persons     249         units          0
# 3  1946-10  Canada  2016A000011124  Persons     249         units          0
# 4  1947-01  Canada  2016A000011124  Persons     249         units          0
#
#   VECTOR  COORDINATE     VALUE  STATUS  SYMBOL TERMINATED  DECIMALS
# 0     v1           1  12188000     NaN     NaN        NaN         0
# 1     v1           1  12241000     NaN     NaN        NaN         0
# 2     v1           1  12316000     NaN     NaN        NaN         0
# 3     v1           1  12393000     NaN     NaN        NaN         0
# 4     v1           1  12450000     NaN     NaN        NaN         0

# %%
pop_est_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3839 entries, 0 to 3838
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   REF_DATE       3839 non-null   object
#  1   GEO            3839 non-null   object
#  2   DGUID          3678 non-null   object
#  3   UOM            3839 non-null   object
#  4   UOM_ID         3839 non-null   int64
#  5   SCALAR_FACTOR  3839 non-null   object
#  6   SCALAR_ID      3839 non-null   int64
#  7   VECTOR         3839 non-null   object
#  8   COORDINATE     3839 non-null   int64
#  9   VALUE          3839 non-null   int64
#  10  STATUS         0 non-null      float64
#  11  SYMBOL         0 non-null      float64
#  12  TERMINATED     161 non-null    object
#  13  DECIMALS       3839 non-null   int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 420.0+ KB

# %%
# Dropping Columns only with null values

pop_est_df.drop(pop_est_df.columns[[10, 11]], axis=1, inplace=True)

# %%
pop_est_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3839 entries, 0 to 3838
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   REF_DATE       3839 non-null   object
#  1   GEO            3839 non-null   object
#  2   DGUID          3678 non-null   object
#  3   UOM            3839 non-null   object
#  4   UOM_ID         3839 non-null   int64
#  5   SCALAR_FACTOR  3839 non-null   object
#  6   SCALAR_ID      3839 non-null   int64
#  7   VECTOR         3839 non-null   object
#  8   COORDINATE     3839 non-null   int64
#  9   VALUE          3839 non-null   int64
#  10  TERMINATED     161 non-null    object
#  11  DECIMALS       3839 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 360.0+ KB

# %%
# Finding number of unique values in each column

pop_est_df.nunique(dropna=True).sort_values()
# Out:
# UOM                 1
# UOM_ID              1
# SCALAR_FACTOR       1
# SCALAR_ID           1
# TERMINATED          1
# DECIMALS            1
# DGUID              14
# GEO                15
# VECTOR             15
# COORDINATE         15
# REF_DATE          306
# VALUE            3529
# dtype: int64

# %%
# Dropping Columns with only one unique value

pop_est_df.drop(pop_est_df.columns[[3,4,5,6,10,11]], axis=1, inplace=True)

# %%
pop_est_df.head(5)
# Out:
#   REF_DATE     GEO           DGUID VECTOR  COORDINATE     VALUE
# 0  1946-01  Canada  2016A000011124     v1           1  12188000
# 1  1946-04  Canada  2016A000011124     v1           1  12241000
# 2  1946-07  Canada  2016A000011124     v1           1  12316000
# 3  1946-10  Canada  2016A000011124     v1           1  12393000
# 4  1947-01  Canada  2016A000011124     v1           1  12450000

# %%
pop_est_df.loc[pop_est_df['REF_DATE'] == '2021-01']
# Out:
#      REF_DATE                        GEO           DGUID VECTOR  COORDINATE  \
# 3755  2021-01                     Canada  2016A000011124     v1           1
# 3756  2021-01  Newfoundland and Labrador     2016A000210     v2           2
# 3757  2021-01       Prince Edward Island     2016A000211     v8           3
# 3758  2021-01                Nova Scotia     2016A000212     v9           4
# 3759  2021-01              New Brunswick     2016A000213    v10           5
# 3760  2021-01                     Quebec     2016A000224    v11           6
# 3761  2021-01                    Ontario     2016A000235    v12           7
# 3762  2021-01                   Manitoba     2016A000246    v13           8
# 3763  2021-01               Saskatchewan     2016A000247    v14           9
# 3764  2021-01                    Alberta     2016A000248    v15          10
# 3765  2021-01           British Columbia     2016A000259     v3          11
# 3766  2021-01                      Yukon     2016A000260     v4          12
# 3767  2021-01      Northwest Territories     2016A000261     v6          14
# 3768  2021-01                    Nunavut     2016A000262     v7          15
#
#          VALUE
# 3755  38068872
# 3756    519664
# 3757    161514
# 3758    982012
# 3759    784156
# 3760   8579370
# 3761  14759431
# 3762   1381459
# 3763   1178971
# 3764   4431454
# 3765   5163919
# 3766     42344
# 3767     45323
# 3768     39255

# %%
#renaming the columns for readability
pop_est_df.rename(columns = {'VALUE':'Population estimate'}, inplace = True)

# %%
pop_est_df.head(5)
# Out:
#   REF_DATE     GEO           DGUID VECTOR  COORDINATE  Population estimate
# 0  1946-01  Canada  2016A000011124     v1           1             12188000
# 1  1946-04  Canada  2016A000011124     v1           1             12241000
# 2  1946-07  Canada  2016A000011124     v1           1             12316000
# 3  1946-10  Canada  2016A000011124     v1           1             12393000
# 4  1947-01  Canada  2016A000011124     v1           1             12450000

# %%
pop_est_df.to_csv('pop_est_df_edited.csv',index=False)

# %%
# housing_df = pd.read_csv('../input/building-construction-price-indexes-canada/18100135.csv')

# %%
# housing_df.head()

# %% [markdown]
# # INFLATION

# %% [markdown]
# # Consumer Price Index, annual average, not seasonally adjusted

# %%
CPI_df = pd.read_csv('../input/consumer-price-index-canada/18100005.csv')
CPI_df.head()
# Out:
#    REF_DATE     GEO           DGUID Products and product groups       UOM  \
# 0      1914  Canada  2016A000011124                   All-items  2002=100
# 1      1914  Canada  2016A000011124        All-items (1992=100)  1992=100
# 2      1914  Canada  2016A000011124          Goods and services  2002=100
# 3      1915  Canada  2016A000011124                   All-items  2002=100
# 4      1915  Canada  2016A000011124        All-items (1992=100)  1992=100
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR  COORDINATE  VALUE  STATUS  \
# 0      17         units          0  v41693271       2.200    6.0     NaN
# 1       7         units          0  v41713433       2.309    7.2     NaN
# 2      17         units          0  v41693519       2.273    6.0     NaN
# 3      17         units          0  v41693271       2.200    6.1     NaN
# 4       7         units          0  v41713433       2.309    7.3     NaN
#
#    SYMBOL TERMINATED  DECIMALS
# 0     NaN        NaN         1
# 1     NaN          t         1
# 2     NaN          t         1
# 3     NaN        NaN         1
# 4     NaN          t         1

# %%
CPI_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86257 entries, 0 to 86256
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REF_DATE                     86257 non-null  int64
#  1   GEO                          86257 non-null  object
#  2   DGUID                        85992 non-null  object
#  3   Products and product groups  86257 non-null  object
#  4   UOM                          86257 non-null  object
#  5   UOM_ID                       86257 non-null  int64
#  6   SCALAR_FACTOR                86257 non-null  object
#  7   SCALAR_ID                    86257 non-null  int64
#  8   VECTOR                       86257 non-null  object
#  9   COORDINATE                   86257 non-null  float64
#  10  VALUE                        86257 non-null  float64
#  11  STATUS                       0 non-null      float64
#  12  SYMBOL                       0 non-null      float64
#  13  TERMINATED                   4970 non-null   object
#  14  DECIMALS                     86257 non-null  int64
# dtypes: float64(4), int64(4), object(7)
# memory usage: 9.9+ MB

# %%
# Finding number of unique values in each column

CPI_df.nunique(dropna=True).sort_values()
# Out:
# STATUS                            0
# SYMBOL                            0
# SCALAR_FACTOR                     1
# SCALAR_ID                         1
# TERMINATED                        1
# DECIMALS                          1
# UOM                               8
# UOM_ID                            8
# DGUID                            29
# GEO                              30
# REF_DATE                        108
# Products and product groups     335
# COORDINATE                     1980
# VECTOR                         2106
# VALUE                          2321
# dtype: int64

# %%
# Dropping Columns with zero and one unique value

CPI_df.drop(CPI_df.columns[[6, 7, 11, 12, 13, 14]], axis=1, inplace=True)

# %%
CPI_df.head()
# Out:
#    REF_DATE     GEO           DGUID Products and product groups       UOM  \
# 0      1914  Canada  2016A000011124                   All-items  2002=100
# 1      1914  Canada  2016A000011124        All-items (1992=100)  1992=100
# 2      1914  Canada  2016A000011124          Goods and services  2002=100
# 3      1915  Canada  2016A000011124                   All-items  2002=100
# 4      1915  Canada  2016A000011124        All-items (1992=100)  1992=100
#
#    UOM_ID     VECTOR  COORDINATE  VALUE
# 0      17  v41693271       2.200    6.0
# 1       7  v41713433       2.309    7.2
# 2      17  v41693519       2.273    6.0
# 3      17  v41693271       2.200    6.1
# 4       7  v41713433       2.309    7.3

# %%
#renaming the columns for readability
CPI_df.rename(columns = {'VALUE':'CPI'}, inplace = True)

# %%
CPI_df.head()
# Out:
#    REF_DATE     GEO           DGUID Products and product groups       UOM  \
# 0      1914  Canada  2016A000011124                   All-items  2002=100
# 1      1914  Canada  2016A000011124        All-items (1992=100)  1992=100
# 2      1914  Canada  2016A000011124          Goods and services  2002=100
# 3      1915  Canada  2016A000011124                   All-items  2002=100
# 4      1915  Canada  2016A000011124        All-items (1992=100)  1992=100
#
#    UOM_ID     VECTOR  COORDINATE  CPI
# 0      17  v41693271       2.200  6.0
# 1       7  v41713433       2.309  7.2
# 2      17  v41693519       2.273  6.0
# 3      17  v41693271       2.200  6.1
# 4       7  v41713433       2.309  7.3

# %%
CPI_df.to_csv('CPI_df_edited.csv',index=False)

# %% [markdown]
# # Immigration
#
# ## Estimates of the components of demographic growth, annual
#
# The components of demographic growth include,
# Births
# Deaths
# Immigrants
# Emigrants
# Returning emigrants
# Net temporary emigrants
# Net interprovincial migration
# Net non-permanent residents
# Residual deviation
#
# ---
# We can extract the immigrant information from there.

# %%
comp_demo_df = pd.read_csv('../input/est-of-the-components-of-demographic-growth-canada/17100008.csv')
comp_demo_df.head(10)
# Out:
#     REF_DATE                        GEO           DGUID  \
# 0  1971/1972                     Canada  2016A000011124
# 1  1971/1972                     Canada  2016A000011124
# 2  1971/1972                     Canada  2016A000011124
# 3  1971/1972                     Canada  2016A000011124
# 4  1971/1972                     Canada  2016A000011124
# 5  1971/1972                     Canada  2016A000011124
# 6  1971/1972                     Canada  2016A000011124
# 7  1971/1972  Newfoundland and Labrador     2016A000210
# 8  1971/1972  Newfoundland and Labrador     2016A000210
# 9  1971/1972  Newfoundland and Labrador     2016A000210
#
#   Components of population growth      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0                          Births  Persons     249         units          0
# 1                          Deaths  Persons     249         units          0
# 2                      Immigrants  Persons     249         units          0
# 3                       Emigrants  Persons     249         units          0
# 4             Returning emigrants  Persons     249         units          0
# 5     Net non-permanent residents  Persons     249         units          0
# 6              Residual deviation  Persons     249         units          0
# 7                          Births  Persons     249         units          0
# 8                          Deaths  Persons     249         units          0
# 9                      Immigrants  Persons     249         units          0
#
#       VECTOR  COORDINATE   VALUE  STATUS  SYMBOL TERMINATED  DECIMALS
# 0    v391069        1.10  351256     NaN     NaN        NaN         0
# 1    v391084        1.20  159533     NaN     NaN        NaN         0
# 2    v391099        1.30  117036     NaN     NaN        NaN         0
# 3  v29768526        1.90   66034     NaN     NaN        NaN         0
# 4  v29768527        1.10   39457     NaN     NaN        NaN         0
# 5  v29768529        1.12    2997     NaN     NaN        NaN         0
# 6  v53437072        1.80   28748     NaN     NaN        NaN         0
# 7    v391070        2.10   12746     NaN     NaN        NaN         0
# 8    v391085        2.20    3269     NaN     NaN        NaN         0
# 9    v391100        2.30     729     NaN     NaN        NaN         0

# %%
comp_demo_df.shape
# Out:
# (5777, 15)

# %%
imm_df = comp_demo_df.copy()
imm_df = comp_demo_df.loc[comp_demo_df['Components of population growth'] == 'Immigrants']

# %%
imm_df.shape
# Out:
# (680, 15)

# %%
imm_df.head()
# Out:
#      REF_DATE                        GEO           DGUID  \
# 2   1971/1972                     Canada  2016A000011124
# 9   1971/1972  Newfoundland and Labrador     2016A000210
# 17  1971/1972       Prince Edward Island     2016A000211
# 25  1971/1972                Nova Scotia     2016A000212
# 33  1971/1972              New Brunswick     2016A000213
#
#    Components of population growth      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 2                       Immigrants  Persons     249         units          0
# 9                       Immigrants  Persons     249         units          0
# 17                      Immigrants  Persons     249         units          0
# 25                      Immigrants  Persons     249         units          0
# 33                      Immigrants  Persons     249         units          0
#
#      VECTOR  COORDINATE   VALUE  STATUS  SYMBOL TERMINATED  DECIMALS
# 2   v391099         1.3  117036     NaN     NaN        NaN         0
# 9   v391100         2.3     729     NaN     NaN        NaN         0
# 17  v391106         3.3     174     NaN     NaN        NaN         0
# 25  v391107         4.3    1709     NaN     NaN        NaN         0
# 33  v391108         5.3    1081     NaN     NaN        NaN         0

# %%
imm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 680 entries, 2 to 5771
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   REF_DATE                         680 non-null    object
#  1   GEO                              680 non-null    object
#  2   DGUID                            660 non-null    object
#  3   Components of population growth  680 non-null    object
#  4   UOM                              680 non-null    object
#  5   UOM_ID                           680 non-null    int64
#  6   SCALAR_FACTOR                    680 non-null    object
#  7   SCALAR_ID                        680 non-null    int64
#  8   VECTOR                           680 non-null    object
#  9   COORDINATE                       680 non-null    float64
#  10  VALUE                            680 non-null    int64
#  11  STATUS                           0 non-null      float64
#  12  SYMBOL                           0 non-null      float64
#  13  TERMINATED                       20 non-null     object
#  14  DECIMALS                         680 non-null    int64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 85.0+ KB

# %%
# Finding number of unique values in each column

imm_df.nunique(dropna=True).sort_values()
# Out:
# STATUS                               0
# SYMBOL                               0
# Components of population growth      1
# UOM                                  1
# UOM_ID                               1
# SCALAR_FACTOR                        1
# SCALAR_ID                            1
# TERMINATED                           1
# DECIMALS                             1
# DGUID                               14
# GEO                                 15
# VECTOR                              15
# COORDINATE                          15
# REF_DATE                            50
# VALUE                              628
# dtype: int64

# %%
# Dropping Columns with zero and one unique value

imm_df.drop(imm_df.columns[[3, 4, 5, 6, 7, 11, 12, 13, 14]], axis=1, inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
imm_df.head()
# Out:
#      REF_DATE                        GEO           DGUID   VECTOR  COORDINATE  \
# 2   1971/1972                     Canada  2016A000011124  v391099         1.3
# 9   1971/1972  Newfoundland and Labrador     2016A000210  v391100         2.3
# 17  1971/1972       Prince Edward Island     2016A000211  v391106         3.3
# 25  1971/1972                Nova Scotia     2016A000212  v391107         4.3
# 33  1971/1972              New Brunswick     2016A000213  v391108         5.3
#
#      VALUE
# 2   117036
# 9      729
# 17     174
# 25    1709
# 33    1081

# %%
#renaming the columns for readability
imm_df.rename(columns = {'VALUE':'Immigration'}, inplace = True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
imm_df.head()
# Out:
#      REF_DATE                        GEO           DGUID   VECTOR  COORDINATE  \
# 2   1971/1972                     Canada  2016A000011124  v391099         1.3
# 9   1971/1972  Newfoundland and Labrador     2016A000210  v391100         2.3
# 17  1971/1972       Prince Edward Island     2016A000211  v391106         3.3
# 25  1971/1972                Nova Scotia     2016A000212  v391107         4.3
# 33  1971/1972              New Brunswick     2016A000213  v391108         5.3
#
#     Immigration
# 2        117036
# 9           729
# 17          174
# 25         1709
# 33         1081

# %%
imm_df = imm_df.reset_index(drop = True)
imm_df.head()
# Out:
#     REF_DATE                        GEO           DGUID   VECTOR  COORDINATE  \
# 0  1971/1972                     Canada  2016A000011124  v391099         1.3
# 1  1971/1972  Newfoundland and Labrador     2016A000210  v391100         2.3
# 2  1971/1972       Prince Edward Island     2016A000211  v391106         3.3
# 3  1971/1972                Nova Scotia     2016A000212  v391107         4.3
# 4  1971/1972              New Brunswick     2016A000213  v391108         5.3
#
#    Immigration
# 0       117036
# 1          729
# 2          174
# 3         1709
# 4         1081

# %%
imm_df.to_csv('imm_df_edited.csv',index=False)

# %% [markdown]
# # References:
# 1. Population and dwelling counts: Canada and population centres1
# (Population centre - Area with a population of at least 1,000 and no fewer than 400 persons per square kilometre.)
# https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=9810001101
#
# 2. Population and dwelling counts: Canada and federal electoral districts (2013 Representation Order)
# https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=9810001001
#
# 3. Structural type of dwelling and household size: Canada, provinces and territories, census metropolitan areas and census agglomerations with parts
# https://www150.statcan.gc.ca/t1/tbl1/en/cv.action?pid=9810004001
#
# 4. Population estimates, quarterly, https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1710000901
#
# 4. Consumer Price Index (CPI) statistics, measures of core inflation and other related statistics - Bank of Canada definitions (2000 - 2022)
# https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810025601&cubeTimeFrame.startMonth=12&cubeTimeFrame.startYear=2000&cubeTimeFrame.endMonth=04&cubeTimeFrame.endYear=2022&referencePeriods=20001201%2C20220401
#
# 5. Consumer Price Index, annual average, not seasonally adjusted, https://www150.statcan.gc.ca/t1/tbl1/en/cv.action?pid=1810000501
#
# 6. Interprovincial migration of immigrant taxfilers, by admission year and tax year, for Canada and provinces
# https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=4310001701
#
# 7. Estimates of the components of demographic growth, annual, https://www150.statcan.gc.ca/t1/tbl1/en/cv.action?pid=1710000801
