# %% [markdown]
# <a href="https://www.kaggle.com/code/aditigulati/aditi-gulati?scriptVersionId=100732872" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/income-afterincome-economic-familytype/income_afterincome_economic_familytype.csv
# /kaggle/input/income-economic-familytype-provinces/income-afterincome-economic-familytype_provices.csv
# /kaggle/input/housing-affordability-in-canada/Structural-dwellings-household-size.csv
# /kaggle/input/housing-affordability-in-canada/HPI 1981-2022 federal and provincial.csv
# /kaggle/input/housing-affordability-in-canada/population_dwellings_count.csv
# /kaggle/input/housing-affordability-in-canada/Interest and mortgage rates 1951-2022.csv
# /kaggle/input/housing-affordability-in-canada/population-by-region-1946-2022.csv
# /kaggle/input/housing-affordability-in-canada/CPI-inflation-by-region-1914-202.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/ottawa_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saguenay_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/calgary_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/prince edward_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/qubec cma_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/thunder bay_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/sherbrooke_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/greater sudbury_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/kingston_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/victoria_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/oshawa_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/edmonton_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/winnipeg_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/gatineau_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/halifax_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/abbotsford_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/hamilton_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/manitoba_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saint john_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/alberta_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/new brunswick_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/peterborough_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/guelph_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saskatchewan_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/nova scotia_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/montral_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/moncton_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/brantford_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/quebec_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/barrie_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saskatoon_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/british columbia_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/vancouver_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/windsor_section1_.csv
# /kaggle/input/income-tax-aftertax-income-economic-family-type/income_afterincome_economic_familytype.xlsx
# /kaggle/input/incomeafterincomeeconomicfamilytype19992020/income-afterincome-economic-familytype1999-2020.csv
# /kaggle/input/income-after-income-economic-familytype/income_afterincome_economic_familytype.csv

# %%
data=pd.read_csv("../input/income-afterincome-economic-familytype/income_afterincome_economic_familytype.csv")

# %%
data.describe()
# Out:
#        Income concept 7 Canada 6  \
# count                         15
# unique                         5
# top         Median market income
# freq                           3
#
#                          Economic family type Geography 5    2000 Symbol  \
# count                                                  15      15     15
# unique                                                  3      15      4
# top     Economic families and persons not in an econom...  51,400      A
# freq                                                    5       1      9
#
#           2001 Symbol.1    2002 Symbol.2    2003 Symbol.3  ...    2016  \
# count       15       15      15       15      15       15  ...      15
# unique      15        4      15        4      15        4  ...      15
# top     51,900        A  51,800        A  51,800        A  ...  55,500
# freq         1       10       1       10       1       10  ...       1
#
#        Symbol.16    2017 Symbol.17   2018 Symbol.18    2019 Symbol.19    2020  \
# count         15      15        15     15        15      15        15      15
# unique         4      15         4     14         4      15         4      15
# top            A  56,300         A  7,500         A  57,600         A  55,700
# freq          11       1        12      2        12       1        11       1
#
#        Symbol.20
# count         15
# unique         2
# top            A
# freq          12
#
# [4 rows x 44 columns]

# %%
data[:10]
# Out:
#      Income concept 7 Canada 6  \
# 0         Median market income
# 1         Median market income
# 2         Median market income
# 3  Median government transfers
# 4  Median government transfers
# 5  Median government transfers
# 6          Median total income
# 7          Median total income
# 8          Median total income
# 9            Median income tax
#
#                     Economic family type Geography 5    2000 Symbol    2001  \
# 0  Economic families and persons not in an econom...  51,400      A  51,900
# 1                                Economic families 8  72,200      A  72,100
# 2                Persons not in an economic family 9  20,000      B  21,400
# 3  Economic families and persons not in an econom...   3,700      B   4,400
# 4                                Economic families 8   4,300      B   5,100
# 5                Persons not in an economic family 9   1,300      E   1,400
# 6  Economic families and persons not in an econom...  59,900      A  61,200
# 7                                Economic families 8  80,100      A  81,500
# 8                Persons not in an economic family 9  28,200      B  29,600
# 9  Economic families and persons not in an econom...   8,200      A   7,600
#
#   Symbol.1    2002 Symbol.2    2003 Symbol.3  ...    2016 Symbol.16    2017  \
# 0        A  51,800        A  51,800        A  ...  55,500         A  56,300
# 1        A  71,300        A  71,300        A  ...  82,700         A  84,800
# 2        B  22,400        B  22,400        B  ...  25,600         B  26,000
# 3        B   4,400        B   4,300        B  ...   7,800         B   8,000
# 4        B   5,000        B   5,000        B  ...   9,500         A  10,000
# 5        E   1,600        E   1,200        E  ...   1,800         D   2,200
# 6        A  60,900        A  60,800        A  ...  67,700         A  69,700
# 7        A  81,000        A  81,300        A  ...  95,800         A  97,800
# 8        A  31,100        A  30,300        A  ...  33,500         A  34,500
# 9        A   7,400        A   7,400        A  ...   7,000         A   7,300
#
#   Symbol.17      2018 Symbol.18      2019 Symbol.19      2020 Symbol.20
# 0         A    57,500         A    57,600         A    55,700         A
# 1         A    86,500         A    86,600         A    84,200         A
# 2         B    26,200         B    26,800         B    23,900         B
# 3         A     7,500         A     8,200         B    16,400         A
# 4         A     9,400         A     9,900         A    20,600         A
# 5         D     2,100         D     2,900         D    11,200         B
# 6         A    70,200         A    70,500         A    75,400         A
# 7         A  1,00,400         A  1,00,000         A  1,06,300         A
# 8         A    34,300         A    35,400         A    37,800         A
# 9         A     7,500         A     7,500         A     8,000         A
#
# [10 rows x 44 columns]

# %% [markdown]
# |Symbol legend:| |
# |-------|------|
# |E|use with caution|
# |A|data quality: excellent|
# |B|data quality: very good|
# |C|data quality: good|
# |D|data quality: acceptable|

# %%
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print("duplicated Series values")
print(data.duplicated().sum())
print()
print("About Features : ")
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (15, 44)
#
# unique elements in Features
#
# Income concept 7 Canada 6            5
# Economic family type Geography 5     3
# 2000                                15
# Symbol                               4
# 2001                                15
# Symbol.1                             4
# 2002                                15
# Symbol.2                             4
# 2003                                15
# Symbol.3                             4
# 2004                                15
# Symbol.4                             4
# 2005                                15
# Symbol.5                             4
# 2006                                15
# Symbol.6                             4
# 2007                                15
# Symbol.7                             3
# 2008                                15
# Symbol.8                             4
# 2009                                15
# Symbol.9                             4
# 2010                                15
# Symbol.10                            3
# 2011                                15
# Symbol.11                            3
# 2012                                15
# Symbol.12                            4
# 2013                                15
# Symbol.13                            4
# 2014                                15
# Symbol.14                            4
# 2015                                15
# Symbol.15                            3
# 2016                                15
# Symbol.16                            4
# 2017                                15
# Symbol.17                            4
# 2018                                14
# Symbol.18                            4
# 2019                                15
# Symbol.19                            4
# 2020                                15
# Symbol.20                            2
# dtype: int64
#
# duplicated Series values
# 0
#
# About Features :
#
# Income concept 7 Canada 6           100.0
# Economic family type Geography 5    100.0
# 2000                                100.0
# Symbol                              100.0
# 2001                                100.0
# Symbol.1                            100.0
# 2002                                100.0
# Symbol.2                            100.0
# 2003                                100.0
# Symbol.3                            100.0
# 2004                                100.0
# Symbol.4                            100.0
# 2005                                100.0
# Symbol.5                            100.0
# 2006                                100.0
# Symbol.6                            100.0
# 2007                                100.0
# Symbol.7                            100.0
# 2008                                100.0
# Symbol.8                            100.0
# 2009                                100.0
# Symbol.9                            100.0
# 2010                                100.0
# Symbol.10                           100.0
# 2011                                100.0
# Symbol.11                           100.0
# 2012                                100.0
# Symbol.12                           100.0
# 2013                                100.0
# Symbol.13                           100.0
# 2014                                100.0
# Symbol.14                           100.0
# 2015                                100.0
# Symbol.15                           100.0
# 2016                                100.0
# Symbol.16                           100.0
# 2017                                100.0
# Symbol.17                           100.0
# 2018                                100.0
# Symbol.18                           100.0
# 2019                                100.0
# Symbol.19                           100.0
# 2020                                100.0
# Symbol.20                           100.0
# dtype: float64

# %%
data.to_csv('income-afterincome-economic-familytype.csv',index=False)

# %%
df=pd.read_csv("../input/income-economic-familytype-provinces/income-afterincome-economic-familytype_provices.csv")

# %%
df.head()
# Out:
#                                Geography 4  \
# 0  Income 2020 constant dollars concept 6
# 1                     Median market income
# 2                     Median market income
# 3                     Median market income
# 4              Median government transfers
#
#                                          Geography 5 Canada 7 Canada 8  \
# 0                               Economic family type     2016     2017
# 1  Economic families and persons not in an econom...  55,500A  56,300A
# 2                                Economic families 8  82,700A  84,800A
# 3                Persons not in an economic family 9  25,600B  26,000B
# 4  Economic families and persons not in an econom...   7,800B   8,000A
#
#   Canada 9 Canada 10 Canada 11 Atlantic provinces Atlantic provinces.1  \
# 0     2018      2019      2020               2016                 2017
# 1  57,500A   57,600A   55,700A            45,500A              45,300A
# 2  86,500A   86,600A   84,200A            67,800A              67,700A
# 3  26,200B   26,800B   23,900B            20,500C              19,800C
# 4   7,500A    8,200B   16,400A            10,800B              12,100A
#
#   Atlantic provinces.2  ... Edmonton, Alberta Edmonton, Alberta.1  \
# 0                 2018  ...              2016                2017
# 1              45,700A  ...           94,200C             73,400C
# 2              68,500A  ...          118,200B            117,900C
# 3              20,300C  ...           41,400D             36,000D
# 4              11,200B  ...            3,300E              2,600E
#
#   Edmonton, Alberta.2 Edmonton, Alberta.3 Edmonton, Alberta.4  \
# 0                2018                2019                2020
# 1             81,700C             74,300D             76,100C
# 2            112,300C            109,000C            102,900C
# 3             37,300D             32,500D             31,800D
# 4              3,200E              4,400E             15,200C
#
#   Vancouver, British Columbia Vancouver, British Columbia.1  \
# 0                        2016                          2017
# 1                     65,200C                       64,200C
# 2                     90,100C                       96,000B
# 3                     28,700D                       28,300D
# 4                      4,600E                        3,000E
#
#   Vancouver, British Columbia.2 Vancouver, British Columbia.3  \
# 0                          2018                          2019
# 1                       59,700C                       67,200C
# 2                       96,600B                       97,400B
# 3                       33,100C                       27,000E
# 4                        2,800E                        3,400E
#
#   Vancouver, British Columbia.4
# 0                          2020
# 1                       61,000B
# 2                       92,500B
# 3                       30,600D
# 4                       14,500C
#
# [5 rows x 107 columns]

# %%
df.describe()
# Out:
#                  Geography 4  \
# count                     16
# unique                     6
# top     Median market income
# freq                       3
#
#                                               Geography 5 Canada 7 Canada 8  \
# count                                                  16       16       16
# unique                                                  4       16       16
# top     Economic families and persons not in an econom...     2016     2017
# freq                                                    5        1        1
#
#        Canada 9 Canada 10 Canada 11 Atlantic provinces Atlantic provinces.1  \
# count        16        16        16                 16                   16
# unique       15        16        16                 16                   16
# top      7,500A      2019      2020               2016                 2017
# freq          2         1         1                  1                    1
#
#        Atlantic provinces.2  ... Edmonton, Alberta Edmonton, Alberta.1  \
# count                    16  ...                16                  16
# unique                   16  ...                16                  16
# top                    2018  ...              2016                2017
# freq                      1  ...                 1                   1
#
#        Edmonton, Alberta.2 Edmonton, Alberta.3 Edmonton, Alberta.4  \
# count                   16                  16                  16
# unique                  16                  16                  16
# top                   2018                2019                2020
# freq                     1                   1                   1
#
#        Vancouver, British Columbia Vancouver, British Columbia.1  \
# count                           16                            16
# unique                          16                            16
# top                           2016                          2017
# freq                             1                             1
#
#        Vancouver, British Columbia.2 Vancouver, British Columbia.3  \
# count                             16                            16
# unique                            16                            16
# top                             2018                          2019
# freq                               1                             1
#
#        Vancouver, British Columbia.4
# count                             16
# unique                            16
# top                             2020
# freq                               1
#
# [4 rows x 107 columns]

# %%
print("Shape of Dataset")
print(df.shape)
print()
print("unique elements in Features")
print()
print(df.nunique())
print()
print("duplicated Series values")
print(df.duplicated().sum())
print()
print("About Features : ")
print()
print(df.count()/df.isna().count()*100)
x=df.count()/df.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (16, 107)
#
# unique elements in Features
#
# Geography 4                       6
# Geography 5                       4
# Canada 7                         16
# Canada 8                         16
# Canada 9                         15
#                                  ..
# Vancouver, British Columbia      16
# Vancouver, British Columbia.1    16
# Vancouver, British Columbia.2    16
# Vancouver, British Columbia.3    16
# Vancouver, British Columbia.4    16
# Length: 107, dtype: int64
#
# duplicated Series values
# 0
#
# About Features :
#
# Geography 4                      100.0
# Geography 5                      100.0
# Canada 7                         100.0
# Canada 8                         100.0
# Canada 9                         100.0
#                                  ...
# Vancouver, British Columbia      100.0
# Vancouver, British Columbia.1    100.0
# Vancouver, British Columbia.2    100.0
# Vancouver, British Columbia.3    100.0
# Vancouver, British Columbia.4    100.0
# Length: 107, dtype: float64

# %%
df.to_csv('income-afterincome-economic-familytype_provinces.csv',index=False)

# %%
df_1999=pd.read_csv("../input/incomeafterincomeeconomicfamilytype19992020/income-afterincome-economic-familytype1999-2020.csv")

# %%
df_1999.head()
# Out:
#                             Geography 4           Canada 5           Canada 6  \
# 0                             Age group  16 years and over  16 years and over
# 1                                   Sex         Both sexes         Both sexes
# 2  Income source(2020 constant dollars)       Total income       Total income
# 3                            Statistics               1999               2000
# 4          Number of persons  (x 1,000)            23,533A            23,892A
#
#             Canada 7           Canada 8           Canada 9          Canada 10  \
# 0  16 years and over  16 years and over  16 years and over  16 years and over
# 1         Both sexes         Both sexes         Both sexes         Both sexes
# 2       Total income       Total income       Total income       Total income
# 3               2001               2002               2003               2004
# 4            24,207A            24,517A            24,848A            25,179A
#
#            Canada 11          Canada 12          Canada 13  ...  \
# 0  16 years and over  16 years and over  16 years and over  ...
# 1         Both sexes         Both sexes         Both sexes  ...
# 2       Total income       Total income       Total income  ...
# 3               2005               2006               2007  ...
# 4            25,583A            25,822A            26,195A  ...
#
#   Vancouver, British Columbia.12 Vancouver, British Columbia.13  \
# 0              16 years and over              16 years and over
# 1                     Both sexes                     Both sexes
# 2                   Total income                   Total income
# 3                           2011                           2012
# 4                         1,976A                         2,029A
#
#   Vancouver, British Columbia.14 Vancouver, British Columbia.15  \
# 0              16 years and over              16 years and over
# 1                     Both sexes                     Both sexes
# 2                   Total income                   Total income
# 3                           2013                           2014
# 4                         2,093A                         2,108A
#
#   Vancouver, British Columbia.16 Vancouver, British Columbia.17  \
# 0              16 years and over              16 years and over
# 1                     Both sexes                     Both sexes
# 2                   Total income                   Total income
# 3                           2015                           2016
# 4                         2,127A                         2,179A
#
#   Vancouver, British Columbia.18 Vancouver, British Columbia.19  \
# 0              16 years and over              16 years and over
# 1                     Both sexes                     Both sexes
# 2                   Total income                   Total income
# 3                           2017                           2018
# 4                         2,200A                         2,237A
#
#   Vancouver, British Columbia.20 Vancouver, British Columbia.21
# 0              16 years and over              16 years and over
# 1                     Both sexes                     Both sexes
# 2                   Total income                   Total income
# 3                           2019                           2020
# 4                         2,290A                         2,314A
#
# [5 rows x 463 columns]

# %%
df_1999.describe()
# Out:
#        Geography 4           Canada 5           Canada 6           Canada 7  \
# count            9                  9                  9                  9
# unique           9                  9                  9                  9
# top      Age group  16 years and over  16 years and over  16 years and over
# freq             1                  1                  1                  1
#
#                  Canada 8           Canada 9          Canada 10  \
# count                   9                  9                  9
# unique                  9                  9                  9
# top     16 years and over  16 years and over  16 years and over
# freq                    1                  1                  1
#
#                 Canada 11          Canada 12          Canada 13  ...  \
# count                   9                  9                  9  ...
# unique                  9                  9                  9  ...
# top     16 years and over  16 years and over  16 years and over  ...
# freq                    1                  1                  1  ...
#
#        Vancouver, British Columbia.12 Vancouver, British Columbia.13  \
# count                               9                              9
# unique                              9                              9
# top                 16 years and over              16 years and over
# freq                                1                              1
#
#        Vancouver, British Columbia.14 Vancouver, British Columbia.15  \
# count                               9                              9
# unique                              9                              9
# top                 16 years and over              16 years and over
# freq                                1                              1
#
#        Vancouver, British Columbia.16 Vancouver, British Columbia.17  \
# count                               9                              9
# unique                              9                              9
# top                 16 years and over              16 years and over
# freq                                1                              1
#
#        Vancouver, British Columbia.18 Vancouver, British Columbia.19  \
# count                               9                              9
# unique                              9                              9
# top                 16 years and over              16 years and over
# freq                                1                              1
#
#        Vancouver, British Columbia.20 Vancouver, British Columbia.21
# count                               9                              9
# unique                              9                              9
# top                 16 years and over              16 years and over
# freq                                1                              1
#
# [4 rows x 463 columns]

# %%
print("Shape of Dataset")
print(df_1999.shape)
print()
print("unique elements in Features")
print()
print(df_1999.nunique())
print()
print("duplicated Series values")
print(df_1999.duplicated().sum())
print()
print("About Features : ")
print()
print(df_1999.count()/df_1999.isna().count()*100)
x=df_1999.count()/df_1999.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (9, 463)
#
# unique elements in Features
#
# Geography 4                       9
# Canada 5                          9
# Canada 6                          9
# Canada 7                          9
# Canada 8                          9
#                                  ..
# Vancouver, British Columbia.17    9
# Vancouver, British Columbia.18    9
# Vancouver, British Columbia.19    9
# Vancouver, British Columbia.20    9
# Vancouver, British Columbia.21    9
# Length: 463, dtype: int64
#
# duplicated Series values
# 0
#
# About Features :
#
# Geography 4                       100.0
# Canada 5                          100.0
# Canada 6                          100.0
# Canada 7                          100.0
# Canada 8                          100.0
#                                   ...
# Vancouver, British Columbia.17    100.0
# Vancouver, British Columbia.18    100.0
# Vancouver, British Columbia.19    100.0
# Vancouver, British Columbia.20    100.0
# Vancouver, British Columbia.21    100.0
# Length: 463, dtype: float64

# %%
df_1999.to_csv('income-afterincome-economic-familytype_1999to2020.csv',index=False)
