# %% [markdown]
# <a href="https://www.kaggle.com/code/dplayer/task-2-rentalpricedata-exploration?scriptVersionId=100792509" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/May2022-Table 1.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/June2022-June2022.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Oct2021-Table 1.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Aug2021-Table 1.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Nov2021-Table 1.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Feb2022-Feb2022.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Apr2022-Apr2022.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Sep2021-Table 1.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Dec2021-Table 1.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Mar2022-Mar2022.csv
# /kaggle/input/rental-ca-vacant-market-rentalprices-data/Jan2022-Jan2022.csv
# /kaggle/input/housing-affordability-in-canada/Structural-dwellings-household-size.csv
# /kaggle/input/housing-affordability-in-canada/HPI 1981-2022 federal and provincial.csv
# /kaggle/input/housing-affordability-in-canada/population_dwellings_count.csv
# /kaggle/input/housing-affordability-in-canada/Interest and mortgage rates 1951-2022.csv
# /kaggle/input/housing-affordability-in-canada/population-by-region-1946-2022.csv
# /kaggle/input/housing-affordability-in-canada/CPI-inflation-by-region-1914-202.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/ottawa_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saguenay_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/calgary_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/prince edward_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/qubec cma_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/thunder bay_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/sherbrooke_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/greater sudbury_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/kingston_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/victoria_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/oshawa_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/edmonton_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/winnipeg_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/gatineau_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/halifax_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/abbotsford_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/hamilton_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/manitoba_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saint john_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/alberta_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/new brunswick_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/peterborough_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/guelph_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saskatchewan_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/nova scotia_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/montral_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/moncton_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/brantford_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/quebec_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/barrie_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/saskatoon_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/british columbia_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/vancouver_section1_.csv
# /kaggle/input/housing-affordability-in-canada/housing-supply-and-rental/housing-supply-and-rental/windsor_section1_.csv
# /kaggle/input/rent-data-statcan-1987-2020/Canada_2_Bed_rent.csv
# /kaggle/input/rent-data-statcan-1987-2020/Canada_3_Bed_rent.csv
# /kaggle/input/rent-data-statcan-1987-2020/Canada_1Bed_rent.csv
# /kaggle/input/rent-data-statcan-1987-2020/Canada_bachelor_rent.csv

# %% [markdown]
# Load data

# %% [markdown]
# ## Context
# rental.ca generates a rental report every month and summarizes rental prices for vacant properties on the market for rent. They list the average price, average month over month (MOM)% and average year over year (YOY)% for 1 bedroom and 2 bedroom properties for major cities. The following data is colleceted from August 2021 until June 2022.
#
# In this notebook I have combined all the data into asingle table.

# %%
## imports
from pathlib import Path

# %%
import re
p = re.compile(r'\D')

# %% [markdown]
# Added a simple cleanup function to remove unnecessary characters within the data. I also add  2 more columns for month and year.

# %%
def cleanupandadddate(file_name, month, year):
    df = pd.read_csv(Path(file_name))
    #print(df)
    try:
        df['1 BED'] = [p.sub('', x) for x in df['1 BED']]
    except TypeError as te:
        print(f"1-BED {te}")
    try:
        df['2 BED'] = [p.sub('', x) for x in df['2 BED']]
    except TypeError as te:
        print(f"2-BED {te}")
    try:
        df['M/M'] = [re.sub(r'%', '', str(x)) for x in df['M/M']]
    except TypeError as te:
        print(f"M/M {te}")
    try:
        df['Y/Y'] = [re.sub(r'%', '', str(x)) for x in df['Y/Y']]
    except TypeError as te:
        print(f"Y/Y {te}")
    try:
        df['M/M.1'] = [re.sub(r'%', '', str(x)) for x in df['M/M.1']]
    except TypeError as te:
        print(f"M/M.1 {te}")
    try:
        df['Y/Y.1'] = [re.sub(r'%', '', str(x)) for x in df['Y/Y.1']]
    except TypeError as te:
        print(f"Y/Y.1 {te}")
    df['Month'] =[month]*df.shape[0]
    df['Year'] = [year]*df.shape[0]
    df.columns = ['City', '1-Bed($)', 'M/M-1-BED(%)', 'Y/Y-1-BED(%)', '2-BED', 'M/M-2-BED(%)', 'Y/Y-2-BED(%)', 'Month', 'Year']
    return df

# %%
updfMay = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/May2022-Table 1.csv', 'May', '2022')
print(updfMay)
# Out:
#               City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%) 2-BED M/M-2-BED(%)  \
# 0        Vancouver     2334         2.37        18.12  3324         6.47
# 1          Toronto     2065         2.08        12.96  2849         2.63
# 2       Burlington     2017         0.00        15.85  2261         0.22
# 3         Oakville     2010         5.29         8.12  2333         0.09
# 4        Etobicoke     1897         2.49        10.68  2446         4.80
# 5          Burnaby     1883        -3.88        15.24  2563         5.39
# 6      Mississauga     1817         0.11         5.27  2211         0.32
# 7           Guelph     1811         3.37        12.91  2179        -0.23
# 8      Victoria BC     1776         0.74         6.86  2736         7.67
# 9           Barrie     1771         0.11         2.02  2084         0.82
# 10         Vaughan     1730         6.86        11.54  2338         6.08
# 11      North York     1725         1.29          4.1  2259         3.62
# 12       Kitchener     1701         5.59        11.39  2037        -1.69
# 13      Surrev. BC     1655         6.64        12.89  2080         5.96
# 14          Oshawa     1646        -0.66        13.83  1862        -2.31
# 15          Ottawa     1645         0.30         3.13  2009        -1.03
# 16         Halifax     1621        -1.22        10.88  1962        -4.94
# 17        Brampton     1570         3.02        -3.38  1906         1.71
# 18        Hamilton     1557         1.96         9.57  1985         0.25
# 19     Scarborough     1497         1.01        -6.03  1968         1.18
# 20        Montréal     1489        -0.80         0.95  1952         0.00
# 21        Kingston     1425         4.47          1.5  1945         0.88
# 22        Gatineau     1402         3.62         0.43  1717         3.62
# 23         Calgary     1387         1.91        13.88  1693         4.57
# 24  St. Catharines     1362         9.22        -0.37  1837         2.17
# 25      London. ON     1282        -3.75         9.57  1692         0.30
# 26       Laval. QC     1243         3.33        -6.54  1635        -0.24
# 27         Windsor     1227         6.51        -2.62  1591         3.65
# 28        Winnipeg     1176         2.98        -0.59  1471         4.03
# 29      Lethbridge     1079         6.52        13.94  1199         5.36
# 30    Edmonton. AB     1050         3.24         3.75  1308         3.81
# 31   Fort McMurray     1006        -9.69        -5.63  1238        -6.57
# 32       Saskatoon      986         0.20         6.48  1138         1.43
# 33        Red Deer      953         1.06        -1.24  1087         0.37
# 34          Regina      946        -0.73        -3.57  1169         2.19
#
#    Y/Y-2-BED(%) Month  Year
# 0         23.71   May  2022
# 1         17.19   May  2022
# 2         11.76   May  2022
# 3          3.37   May  2022
# 4         15.87   May  2022
# 5         14.52   May  2022
# 6          7.64   May  2022
# 7         16.09   May  2022
# 8           nan   May  2022
# 9         -3.43   May  2022
# 10        10.44   May  2022
# 11         8.82   May  2022
# 12        17.34   May  2022
# 13          nan   May  2022
# 14         0.32   May  2022
# 15          0.9   May  2022
# 16          4.2   May  2022
# 17          4.9   May  2022
# 18         7.07   May  2022
# 19         5.02   May  2022
# 20        -2.55   May  2022
# 21        19.33   May  2022
# 22         7.04   May  2022
# 23        13.85   May  2022
# 24         7.49   May  2022
# 25         3.36   May  2022
# 26        -8.35   May  2022
# 27         7.57   May  2022
# 28         0.41   May  2022
# 29        11.53   May  2022
# 30         3.73   May  2022
# 31        -1.98   May  2022
# 32         3.36   May  2022
# 33          1.4   May  2022
# 34         0.09   May  2022

# %%
updfApr = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/Apr2022-Apr2022.csv', 'April', '2022')
print(updfApr)
# Out:
#               City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%) 2-BED M/M-2-BED(%)  \
# 0        Vancouver     2280         1.83        13.94  3122         2.36
# 1          Toronto     2023        -1.03        10.97  2776        -0.07
# 2       Burlington     2017         8.67        12.74  2256        -1.01
# 3          Burnaby     1959        -1.01        16.47  2432         1.42
# 4         Oakville     1909        -0.68         8.71  2331        -3.72
# 5        Etobicoke     1851        -0.48         8.18  2334        -4.81
# 6      Mississauga     1815         2.20         4.01  2204         0.50
# 7           Barrie     1769        -0.11         3.21  2067         1.87
# 8         Victoria     1763         6.14         7.63  2541        -4.72
# 9           Guelph     1752         1.33          9.3  2184         3.41
# 10          Oshawa     1657        -9.06         18.7  1906         3.25
# 11            Aiax     1650         2.61         2.42  1908        -1.29
# 12         Halifax     1641        -1.32        17.33  2064         1.78
# 13          Ottawa     1640        -3.07         5.94  2030        -0.15
# 14       Brantford     1614        -1.53        10.93  1799         1.07
# 15       Kitchener     1611         2.22         6.69  2072         9.69
# 16          Surrey     1552         6.08         8.38  1963         1.66
# 17    Hamilton. ON     1527         0.86         7.92  1980         2.06
# 18        Brampton     1524         0.66         -3.3  1874        -0.74
# 19         Markham     1512        -1.56       -14.09  2134        -2.24
# 20        Montréal     1501        -0.99         5.41  1952        -2.11
# 21     Scarborough     1482        -2.82        -5.84  1945        -0.56
# 22        Kingston     1364        -4.88         3.41  1928         1.00
# 23         Calgary     1361         7.42         10.2  1619         6.94
# 24        Gatineau     1353        -3.36         9.55  1657        -5.75
# 25      London. ON     1332        -2.27        15.83  1687         1.20
# 26  St. Catharines     1247        -2.27       -10.22  1798         3.39
# 27         Windsor     1152        -6.95       -10.28  1535        -3.09
# 28        Winnipeg     1142        -2.14         2.64  1414        -1.46
# 29    Edmonton. AB     1017        -2.02          0.3  1260         0.24
# 30  Lethbridge. AB     1013         1.30         6.97  1138        -1.47
# 31       Saskatoon      984         2.18         12.2  1122        -0.71
# 32          Regina      953        -1.35        -3.74  1144        -1.55
# 33        Red Deer      943         0.21        -2.58  1083         3.14
# 34    Lloydminster      744         0.68        -4.98   853         0.24
#
#    Y/Y-2-BED(%)  Month  Year
# 0         17.59  April  2022
# 1         16.15  April  2022
# 2         12.46  April  2022
# 3          9.85  April  2022
# 4         10.95  April  2022
# 5          9.42  April  2022
# 6          7.83  April  2022
# 7          7.99  April  2022
# 8           nan  April  2022
# 9          11.2  April  2022
# 10         1.17  April  2022
# 11         -3.1  April  2022
# 12        16.41  April  2022
# 13         2.16  April  2022
# 14          nan  April  2022
# 15        19.22  April  2022
# 16        20.58  April  2022
# 17        10.61  April  2022
# 18         6.72  April  2022
# 19         9.27  April  2022
# 20        -0.71  April  2022
# 21         4.18  April  2022
# 22        12.29  April  2022
# 23         9.32  April  2022
# 24         1.78  April  2022
# 25         4.78  April  2022
# 26        10.37  April  2022
# 27        -0.13  April  2022
# 28        -4.14  April  2022
# 29         2.02  April  2022
# 30         3.93  April  2022
# 31         4.47  April  2022
# 32         0.18  April  2022
# 33         1.03  April  2022
# 34        -5.33  April  2022

# %%
df = pd.read_csv(Path('/kaggle/input/rental-ca-vacant-market-rentalprices-data/Aug2021-Table 1.csv'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   City    35 non-null     object
#  1   1 BED   35 non-null     object
#  2   M/M     35 non-null     object
#  3   Y/Y     34 non-null     object
#  4   2 BED   35 non-null     int64
#  5   M/M.1   35 non-null     object
#  6   Y/Y.1   34 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.0+ KB

# %%
updfAug = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/Aug2021-Table 1.csv', 'August', '2021')
print(updfAug)
# Out:
# 2-BED expected string or bytes-like object
#                City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%)  2-BED M/M-2-BED(%)  \
# 0     Vancouver. BC     2185          6.3         14.4   3041           10
# 1           Toronto     1855          1.0         -9.0   2606          4.2
# 2         Etobicoke     1802          2.8         -7.2   2361          3.6
# 3          Victoria     1756          8.7         11.6   2103          2.0
# 4       Mississauga     1753         -0.3         -9.3   2129          1.6
# 5        Burlington     1745         -2.2        -10.7   2065         -0.8
# 6            Guelph     1714          2.2         10.2   2000          2.1
# 7           Vaughan     1699          9.2         -9.2   2115         -2.3
# 8           Burnaby     1672          0.2         -3.7   2244          0.1
# 9        North York     1669         -0.1         -9.7   2025         -0.3
# 10  New Westminster     1668          4.8         10.9   2010         -5.7
# 11           Ottawa     1611          1.3         -3.4   2033          3.2
# 12      Scarborough     1586          0.2         -5.4   1852         -1.9
# 13          Halifax     1576          2.9          nan   2033          5.7
# 14         Brampton     1557         -1.9         -5.3   1793         -2.9
# 10          Burnaby      1696        -3.58        -0.47  2414         5.88
# 11         Victoria      1695        -9.02         8.10  2563         5.39
# 12       North York      1659        -3.77         -9.2  2120         0.43
# 13          Halifax      1652         0.92         7.34  1953         1.30
# 14           Ottawa      1600        -1.23        -0.62  2027        -0.05
# 15        Kitchener      1555        -2.14        15.01  1897         4.40
# 16         Brampton      1552        -1.77         5.51  1875         0.43
# 17         Waterloo      1551         3.47          nan  1999         7.42
# 18       Surrev. BC      1501        -4.39        -0.27  1935         2.65
# 19  New Westminster      1489        -7.97         0.13  2032        -2.78
# 20         Montréal      1482        -1.72         1.58  1949         1.51
# 21         Hamilton      1482        -4.94         2.35  1900         1.50
# 22     Gatineau. OC      1385        -2.33         1.17  1799         0.90
# 23       London. ON      1364         5.57          nan  1641         0.67
# 24          Calgary      1233        -1.83         2.84  1551        -1.59
# 25      Windsor. ON      1230         -1.6        11.41  1624         0.81
# 26   St. Catharines      1193       -15.33       -14.72  1649        -3.51
# 27         Winnipeg      1144        -0.35        -0.61  1458        -1.22
# 28         Edmonton      1023        -0.49        -1.73  1258        -0.40
# 29       Lethbridge      1003        -3.56         5.25  1180         0.94
# 30    Saskatoon. SK       935        -0.74         3.66  1098         0.73
# 31        Reqina.SK       915        -2.24        -4.98  1136         0.26
# 32         Red Deer       912         -4.3        -4.30  1115         3.05
# 33   Grande Prairie       825        -7.92       -13.97  1099         2.90
# 34     Lloydminster       742        -1.46        -1.20   854        -1.84
#
#    Y/Y-2-BED(%)     Month  Year
# 0         10.71  December  2021
# 1         11.09  December  2021
# 2          3.38  December  2021
# 3         11.90  December  2021
# 4          1.81  December  2021
# 5          0.33  December  2021
# 6         -1.53  December  2021
# 7         -2.28  December  2021
# 8         12.84  December  2021
# 9          5.94  December  2021
# 10         9.83  December  2021
# 11          nan  December  2021
# 12       -12.97  December  2021
# 13        -2.45  December  2021
# 14         1.91  December  2021
# 15        13.87  December  2021
# 16         3.14  December  2021
# 17        14.95  December  2021
# 18         9.14  December  2021
# 19         3.67  December  2021
# 20         3.23  December  2021
# 21        -8.17  December  2021
# 22          nan  December  2021
# 23         2.63  December  2021
# 24         3.75  December  2021
# 25         7.41  December  2021
# 26         9.86  December  2021
# 27        -1.02  December  2021
# 28        -1.87  December  2021
# 29         6.12  December  2021
# 30         3.00  December  2021
# 31        -1.13  December  2021
# 32         9.53  December  2021
# 33        -1.61  December  2021
# 34        -7.87  December  2021

# %%
updfFeb = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/Feb2022-Feb2022.csv', 'February', '2022')
print(updfFeb)
# Out:
# 1-BED expected string or bytes-like object
# 2-BED expected string or bytes-like object
#               City  1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%)  2-BED M/M-2-BED(%)  \
# 0        Vancouver      2163        -0.60         9.24   3003         0.67
# 1          Toronto      2027         0.70        11.50   2769         1.99
# 2         Oakville      1959         2.83         9.69   2388        -0.50
# 3        Etobicoke      1857         0.00         5.09   2424         0.66
# 32         1.58  January  2022
# 33         0.00  January  2022
# 34        -6.46  January  2022

# %%
updfJun = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/June2022-June2022.csv', 'June', '2022')
print(updfJun)
# Out:
#               City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%) 2-BED M/M-2-BED(%)  \
# 0        Vancouver     2377          1.8         19.9  3495          5.1
# 1          Toronto     2133          3.3         15.7  3002          5.4
# 2          Burnaby     2012          6.9         24.1  2645          3.2
# 3         Oakville     2011          0.0          8.2  2445          4.8
# 4       Burlington     1978         -1.9         11.0  2331          3.1
# 5        Etobicoke     1972          4.0         14.0  2586          5.7
# 6           Guelph     1950          7.7         19.6  2156          -11
# 7    Richmond Hill     1928          2.9         20.3  2296          5.3
# 8         Victoria     1870          5.3         13.4  2896          5.8
# 9      Mississauga     1855          2.1          5.6  2282          3.2
# 10       Kitchener     1839          8.1         22.4  2179          7.0
# 11      North York     1781          3.2           79  2367          4.8
# 12         Vaughan     1720         -0.6          6.0  2226         -4.8
# 13          London     1678          nan          nan  2023         19.6
# 14          Ottawa     1674          1.8          3.5  2074          3.2
# 15          Barrie     1673         -5.5        -14.5  2431         16.7
# 16         Halifax     1669          3.0         13.4  2037          3.8
# 17          Oshawa     1663          1.0          8.1  1903          2.2
# 18          Surrev     1642         -0.8          9.6  2137          2.7
# 19        Hamilton     1603          3.0         11.1  2063          3.9
# 20        Brampton     1591          1.3         -2.1  1941          1.8
# 21        Montréal     1538          3.3          4.2  2012          3.1
# 22        Gatineau     1481          5.6          9.1  1796          4.6
# 23         Calgary     1471          6.1         20.7  1794          6.0
# 24  St. Catharines     1451          6.5           72  1899          3.4
# 25        Kingston     1380         -3.2         -5.2  1953          0.4
# 26           Laval     1272          2.3         -5.4  1676          2.5
# 27        Winnipeg     1187          0.9          1.4  1500          2.0
# 28   Fort McMurray     1073          6.7            7  1316          6.3
# 29         Windsor     1159         -5.5          -87  1669           49
# 30        Edmonton     1043         -0.7          4.7  1309            1
# 31      Lethbridge     1043         -3.3          9.0  1210          0.9
# 32          Regina      990          4.7          1.7  1209          3.4
# 33        Red Deer      988          3.7          121  1147          5.5
# 34       Saskatoon      975         -1.1          5.0  1145          0.6
#
#    Y/Y-2-BED(%) Month  Year
# 0          24.1  June  2022
# 1          21.5  June  2022
# 2          18.9  June  2022
# 3           8.9  June  2022
# 4          13.3  June  2022
# 5          17.4  June  2022
# 6          12 9  June  2022
# 7            72  June  2022
# 8           nan  June  2022
# 9          10.7  June  2022
# 10         23.7  June  2022
# 11         14.5  June  2022
# 12          4.2  June  2022
# 13         25.0  June  2022
# 14          4.7  June  2022
# 15         19.7  June  2022
# 16          9.7  June  2022
# 17         17.5  June  2022
# 18          nan  June  2022
# 19         10.0  June  2022
# 20          6.9  June  2022
# 21          2.7  June  2022
# 22         12.8  June  2022
# 23         17.3  June  2022
# 24         12.2  June  2022
# 25         18.9  June  2022
# 26         -6.2  June  2022
# 27          2.0  June  2022
# 20        17.04  March  2022
# 21         7.92  March  2022
# 22         3.09  March  2022
# 23        -3.75  March  2022
# 24        13.73  March  2022
# 25          0.6  March  2022
# 26         5.11  March  2022
# 27        -4.46  March  2022
# 28        -1.26  March  2022
# 29         7.04  March  2022
# 30        -0.51  March  2022
# 31         3.86  March  2022
# 32         5.53  March  2022
# 33        -1.45  March  2022
# 34         -7.1  March  2022

# %%
updfNov = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/Nov2021-Table 1.csv', 'November', '2021')
print(updfNov)
# Out:
# 2-BED expected string or bytes-like object
#                City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%)  2-BED M/M-2-BED(%)  \
# 0         Vancouver     2216          2.8         16.6   3057          4.3
# 1           Toronto     2006          3.5          4.3   2678          1.9
# 2          Oakville     1984          0.3          2.9   2346          0.0
# 3        Burlington     1888          3.5          2.1   2244          1.6
# 4      Victoria. BC     1863          8.6         19.4   2432         -7.0
# 5           Vaughan     1828         -1.6         11.6   2077         -2.1
# 6       Mississauga     1824          0.9         -2.8   2160         -0.9
# 7         Etobicoke     1769         -1.6         -5.0   2303         -2.4
# 8            Guelph     1766          3.5         11.3   2115          5.3
# 9           Burnaby     1759         -4.0          6.7   2280         -3.6
# 10      Markham. ON     1724         -4.4         -2.6   2003         -7.2
# 11       North York     1724          0.6         -9.4   2111          1.2
# 12          Halifax     1637          4.0         17.5   1928         -5.6
# 13           Ottawa     1620         -0.2          1.8   2028         -0.4
# 14  New Westminster     1618          1.1          3.4   2090          nan
# 15      Scarborough     1594         -1.6         -2.3   1917         -1.6
# 16        Kitchener     1589          5.0          8.0   1817         -2.3
# 17         Brampton     1580         -2.6          0.9   1867         -0.2
# 18       Gloucester     1571         -7.0          8.2   2035        -10.8
# 19           Surrey     1570         -3.2          3.5   1885          0.7
# 20         Hamilton     1559          0.4          4.5   1872          2.7
# 21         Montréal     1508          0.1          2.3   1920          0.1
# 22           Oshawa     1426         -4.1         -4.1   1854         -1.9
# 23     Gatineau. OC     1418         -2.7          9.9   1783          -12
# 24   St. Catharines     1409          2.3          7.3   1709         -1.8
# 25       London. ON     1292         -0.9          9.9   1630          3.0
# 26          Calgary     1256         -0.5          4.8   1576          1.3
# 27          Windsor     1250         -5.7         14.5   1611         -1.0
# 28         Winnipeg     1148         -0.7          4.9   1476          0.9
# 29       Lethbridge     1040          5.6          9.6   1169          3.1
# 30     Edmonton. AB     1028          0.7         -0.2   1263          1.5
# 31         Red Deer      953          0.3          4.6   1082         -2.3
# 32        Saskatoon      942          4.6          2.6   1090          3.0
# 33           Regina      936          -43         -1.5   1133         -1.7
# 34     Lloydminster      753          3.9          1.0    870          3.2
#
#    Y/Y-2-BED(%)     Month  Year
# 0          12.7  November  2021
# 1           5.2  November  2021
# 2           4.2  November  2021
# 3           9.8  November  2021
# 4          18.2  November  2021
# 5           1.3  November  2021
# 6           0.4  November  2021
# 7            -1  November  2021
# 8          10.2  November  2021
# 9           1.5  November  2021
# 10         -0.9  November  2021
# 11         -3.7  November  2021
# 12          3.6  November  2021
# 13          1.9  November  2021
# 14          3.4  November  2021
# 15         -2.1  November  2021
# 16           10  November  2021
# 17         -1.3  November  2021
# 18         17.7  November  2021
# 19          6.1  November  2021
# 20        -11.1  November  2021
# 21          2.0  November  2021
# 22         17.6  November  2021
# 23          nan  November  2021
# 24         13.1  November  2021
# 25          1.8  November  2021
# 26          7.1  November  2021
# 27          1.9  November  2021
# 28          3.1  November  2021
# 29          5.9  November  2021
# 30         -1.4  November  2021
# 31          5.8  November  2021
# 32         -0.5  November  2021
# 33            7  November  2021
# 34         -3.0  November  2021

# %%
updfOct = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/Oct2021-Table 1.csv', 'October', '2021')
print(updfOct)
# Out:
#                  City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%) 2-BED M/M-2-BED(%)  \
# 0           Vancouver     2155         -0.5         11.0  2932         -3.7
# 1             Toronto     1938         -2.6         -1.5  2628          0.0
# 2             Vaughan     1858          0.4          7.4  2122         -0.1
# 3             Burnaby     1833          3.8          8.5  2366          1.0
# 4          Burlington     1823         -0.5         -3.2  2209          0.2
# 5         Mississauga     1809          1.1         -6.4  2180         -0.3
# 6             Markham     1803          2.5          2.3  2157          9.3
# 7           Etobicoke     1797         -1.1         -4.9  2360          4.0
# 8            Victoria     1715          nan          6.1  2614          nan
# 9      North York. ON     1714          1.9         -5.7  2086          1.8
# 10             Guelph     1706         -1.3         10.7  2009         -1.3
# 11         Gloucester     1689          1.7          nan  2282          2.5
# 12             Ottawa     1623          1.5         -1.9  2036          1.5
# 13         Surrev. BC     1623          2.3          nan  1873          6.7
# 14           Brampton     1622          2.9          0.5  1870          2.0
# 15           Waterloo     1607         -3.4         -2.3  1955          4.4
# 16            Halifax     1574          3.8         12.5  2041          9.7
# 17       Hamilton. ON     1552          5.8          4.8  1822          2.2
# 18             Nepean     1533         -2.7         -3.8  1820         -0.9
# 19          Kitchener     1514         -2.3          0.7  1861          0.6
# 20           Montréal     1506          3.1          1.5  1918          1.0
# 21         Oshawa. ON     1487         -3.9          9.3  1890          2.5
# 22           Gatineau     1457          5.9          nan  1805          5.2
# 23           Kingston     1358         -5.6           -5  1792          2.4
# 24            Windsor     1325         -4.5          nan  1628          8.8
# 25         London. ON     1304          0.2          8.6  1583         -2.3
# 26              Laval     1296         -5.1        -12.0  1742          5.5
# 27            Calgary     1262          2.6          5.7  1555         -1.5
# 28           Winnipeg     1156         -0.7          6.8  1463          0.4
# 29  Saint-Laurent. OC     1117          3.3          0.5  1528         -2.3
# 30       Edmonton. AB     1021          1.0         -1.5  1245           -1
# 31         Lethbridge      984          nan          3.0  1133          1.4
# 32             Regina      978          2.7          3.9  1153          0.9
# 33           Red Deer      950          3.9          2.7  1108          5.8
# 34          Saskatoon      900          1.2          0.7  1059          1.3
#
#    Y/Y-2-BED(%)    Month  Year
# 0           8.1  October  2021
# 1            21  October  2021
# 2          -0.4  October  2021
# 3           7.5  October  2021
# 4           9.9  October  2021
# 5           1.2  October  2021
# 6           3.7  October  2021
# 7           0.3  October  2021
# 8           nan  October  2021
# 9          -4.4  October  2021
# 10          9.2  October  2021
# 11          nan  October  2021
# 12         -3.4  October  2021
# 13          2.5  October  2021
# 14         -1.8  October  2021
# 15         15.0  October  2021
# 16         17.2  October  2021
# 17        -18.6  October  2021
# 18          0.4  October  2021
# 19         13.7  October  2021
# 20         -0.2  October  2021
# 21         13.8  October  2021
# 22          nan  October  2021
# 23          8.1  October  2021
# 24         12.7  October  2021
# 25          0.1  October  2021
# 26          8.9  October  2021
# 27          5.4  October  2021
# 28          6.4  October  2021
# 29          1.2  October  2021
# 30         -2.0  October  2021
# 31          4.3  October  2021
# 32          2.7  October  2021
# 33          6.1  October  2021
# 34         -3.4  October  2021

# %%
updfSep = cleanupandadddate('/kaggle/input/rental-ca-vacant-market-rentalprices-data/Sep2021-Table 1.csv', 'September', '2021')
print(updfSep)
# Out:
# 1-BED expected string or bytes-like object
# 2-BED expected string or bytes-like object
#                City  1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%)  2-BED M/M-2-BED(%)  \
# 0         Vancouver      2167         -0.8         15.7   3044          0.1
# 1           Toronto      1989          7.2         -1.2   2628          0.8
# 2           Vaughan      1850          8.9          5.3   2124          0.5
# 3        Burlington      1832          5.0         -4.9   2205          6.8
# 4         Etobicoke      1816          0.8         -6.2   2269         -3.9
# 5       Mississauga      1790          2.1         -7.2   2187          2.7
# 6           Burnaby      1765          5.6          5.1   2341          4.3
# 7           Markham      1760         -1.4         -4.7   1974         -0.1
# 8            Guelph      1728          0.8         13.4   2035          1.8
# 9        North York      1681          0.8        -10.0   2049          1.2
# 10  New Westminster      1623         -2.7          5.7   1984         -1.3
# 11      Scarborough      1605          1.2         -5.0   1906          2.9
# 12           Ottawa      1598         -0.8         -1.8   2005         -1.4
# 13           Surrey      1586          2.6          nan   1756          0.2
# 14           Nepean      1576          1.7          0.9   1836         -0.9
# 15         Brampton      1576          1.2         -5.5   1833          2.2
# 16        Kitchener      1550          4.2          4.3   1849          4.6
# 17           Oshawa      1548          2.9          nan   1843         10.2
# 18          Halifax      1515         -3.8          8.6   1860         -8.5
# 19         Hamilton      1468          0.4         -2.6   1783          1.2
# 20         Montréal      1461          3.0         -1.8   1900          2.5
# 21         Kingston      1439         15.6          6.6   1750         -2.5
# 22          Windsor      1388          1.2          nan   1496         -6.1
# 23         Gatineau      1377          6.8          nan   1717          4.9
# 24            Laval      1366          1.6          1.3   1651         -2.5
# 25           London      1302          6.4          6.6   1620         -2.8
# 26          Calgary      1231         -1.2          4.0   1580         -2.6
# 27         Winnipeg      1164         -1.2          6.4   1458         -0.2
# 28         Edmonton      1011         -1.6         -1.4   1246          0.4
# 29           Regina       952         -2.4         -2.1   1143         -1.5
# 30         Red Deer       914          1.5          9.9   1047         -0.4
# 31   Grande Prairie       895         -4.5        -11.2   1080         -3.1
# 32        Saskatoon       890         -2.9          0.7   1046         -1.0
# 33       St. John's       842         -5.1         -5.7    938         -1.6
# 34     Lloydminster       718         -0.4         -3.1    827         -0.9
#
#    Y/Y-2-BED(%)      Month  Year
# 0          12.4  September  2021
# 1          -1.3  September  2021
# 2          -5.4  September  2021
# 3          10.5  September  2021
# 4          -7.8  September  2021
# 5           1.4  September  2021
# 6           7.2  September  2021
# 7           nan  September  2021
# 8          16.1  September  2021
# 9          -8.7  September  2021
# 10         -7.7  September  2021
# 11         -4.7  September  2021
# 12         -5.6  September  2021
# 13          nan  September  2021
# 14          2.3  September  2021
# 15         -3.5  September  2021
# 16         10.6  September  2021
# 17         13.2  September  2021
# 18          4.4  September  2021
# 19        -19.3  September  2021
# 20         -2.9  September  2021
# 21          4.7  September  2021
# 22          5.0  September  2021
# 23          nan  September  2021
# 24          3.7  September  2021
# 25          0.6  September  2021
# 26         11.2  September  2021
# 27         11.1  September  2021
# 28         -2.8  September  2021
# 29         -2.3  September  2021
# 30          9.0  September  2021
# 31         -8.6  September  2021
# 32         -4.9  September  2021
# 33         -9.5  September  2021
# 34         -6.0  September  2021

# %% [markdown]
# ## Combine the data here

# %%
full_data = pd.concat([updfAug, updfSep, updfOct, updfNov, updfDec, updfJan, updfFeb, updfMar, updfApr, updfMay, updfJun])

# %%
print(full_data)
# Out:
#              City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%) 2-BED M/M-2-BED(%)  \
# 0   Vancouver. BC     2185          6.3         14.4  3041           10
# 1         Toronto     1855          1.0         -9.0  2606          4.2
# 2       Etobicoke     1802          2.8         -7.2  2361          3.6
# 3        Victoria     1756          8.7         11.6  2103          2.0
# 4     Mississauga     1753         -0.3         -9.3  2129          1.6
# ..            ...      ...          ...          ...   ...          ...
# 30       Edmonton     1043         -0.7          4.7  1309            1
# 31     Lethbridge     1043         -3.3          9.0  1210          0.9
# 32         Regina      990          4.7          1.7  1209          3.4
# 33       Red Deer      988          3.7          121  1147          5.5
# 34      Saskatoon      975         -1.1          5.0  1145          0.6
#
#    Y/Y-2-BED(%)   Month  Year
# 0          14.5  August  2021
# 1          -3.2  August  2021
# 2          -4.3  August  2021
# 3           4.6  August  2021
# 4          -2.4  August  2021
# ..          ...     ...   ...
# 30          6.4    June  2022
# 31         14.2    June  2022
# 32          3.7    June  2022
# 33          9.0    June  2022
# 34          7.6    June  2022
#
# [385 rows x 9 columns]

# %%
edited_full_data = full_data

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Surrev", case=False), 'City'] = 'Surrey'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Victoria", case=False), 'City'] = 'Victoria'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("VAncouver", case=False), 'City'] = 'Vancouver'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Oshawa", case=False), 'City'] = 'Oshawa'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Saint", case=False), 'City'] = 'Saint-Laurent'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("North York", case=False), 'City'] = 'North York'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Windsor", case=False), 'City'] = 'Windsor'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Laval", case=False), 'City'] = 'Laval'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Aiax", case=False), 'City'] = 'Ajax'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Halifax", case=False), 'City'] = 'Halifax'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Red", case=False), 'City'] = 'Red Deer'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Reqina", case=False), 'City'] = 'Regina'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("St.John", case=False), 'City'] = "St. John's"

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Markham", case=False), 'City'] = 'Markham'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Montreal", case=False), 'City'] = 'Montréal'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Burnabv", case=False), 'City'] = 'Burnaby'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Hamilton", case=False), 'City'] = 'Hamilton'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Edmonton", case=False), 'City'] = 'Edmonton'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("London", case=False), 'City'] = 'London'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Calaarv", case=False), 'City'] = 'Calgary'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Gatineau", case=False), 'City'] = 'Gatineau'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Lethbridge", case=False), 'City'] = 'Lethbridge'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Saskatoon", case=False), 'City'] = 'Saskatoon'

# %%
edited_full_data.loc[edited_full_data['City'].str.contains("Saskatoon", case=False)]
# Out:
#          City 1-Bed($) M/M-1-BED(%) Y/Y-1-BED(%) 2-BED M/M-2-BED(%)  \
# 31  Saskatoon      916         -2.6          1.8  1056         -1.4
# 32  Saskatoon      890         -2.9          0.7  1046         -1.0
# 34  Saskatoon      900          1.2          0.7  1059          1.3
# 32  Saskatoon      942          4.6          2.6  1090          3.0
# 30  Saskatoon      935        -0.74         3.66  1098         0.73
# 32  Saskatoon      951         1.71         6.61  1095        -0.27
# 30  Saskatoon      949        -0.21         3.83   111         1.55
# 31  Saskatoon      963         1.48         4.11  1130         1.62
# 31  Saskatoon      984         2.18         12.2  1122        -0.71
# 32  Saskatoon      986         0.20         6.48  1138         1.43
# 34  Saskatoon      975         -1.1          5.0  1145          0.6
#
#    Y/Y-2-BED(%)      Month  Year
# 31         -5.1     August  2021
# 32         -4.9  September  2021
# 34         -3.4    October  2021
# 32         -0.5   November  2021
# 30         3.00   December  2021
# 32         1.58    January  2022
# 30         1.37   February  2022
# 31         3.86      March  2022
# 31         4.47      April  2022
# 32         3.36        May  2022
# 34          7.6       June  2022

# %%
edited_full_data.City.value_counts()
# Out:
# Vancouver          11
# London             11
# Winnipeg           11
# Montréal           11
# Hamilton           11
# Kitchener          11
# Edmonton           11
# Brampton           11
# Halifax            11
# Toronto            11
# Ottawa             11
# Saskatoon          11
# Mississauga        11
# Etobicoke          11
# Calgary            11
# Regina             10
# North York         10
# Burnaby            10
# Red Deer           10
# Oshawa             10
# Gatineau           10
# Victoria           10
# Lethbridge          9
# Burlington          9
# Vaughan             9
# Guelph              9
# Laval               8
# Windsor             8
# Surrey              8
# Lloydminster        8
# Kingston            8
# Oakville            7
# Scarborough         7
# Markham             6
# St. Catharines      6
# Grande Prairie      5
# Fort McMurray       5
# Barrie              5
# St. John's          4
# New Westminster     4
# Nepean              4
# Waterloo            3
# Gloucester          3
# Saint-Laurent       2
# Richmond Hill       2
# Brantford           2
# Ajax                2
# Niagara Falls       1
# Greater Sudbury     1
# Québec City         1
# Coquitlam           1
# East York           1
# York. ON            1
# Recina              1
# Name: City, dtype: int64

# %%
edited_full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 385 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          385 non-null    object
#  1   1-Bed($)      385 non-null    object
#  2   M/M-1-BED(%)  385 non-null    object
#  3   Y/Y-1-BED(%)  385 non-null    object
#  4   2-BED         385 non-null    object
#  5   M/M-2-BED(%)  385 non-null    object
#  6   Y/Y-2-BED(%)  385 non-null    object
#  7   Month         385 non-null    object
#  8   Year          385 non-null    object
# dtypes: object(9)
# memory usage: 30.1+ KB

# %%
edited_full_data.to_csv('rental_ca_prices_Aug2021-Jun2022.csv')

# %% [markdown]
# ### Addendum

# %% [markdown]
# The following data is sourced from a differnt location https://themeasureofaplan.com/rent-prices-versus-income/
#
# They have done some analysis of rent prices vs income. However, their original datasets had a cleaned up version of rent prices which was taken from statcan.
# I pulled the rent prices data here.
#
# Below I am putting everything together. I have chosen to build a dataset for 10 years starting from 2010 until 2020. But we can go higher if we want. Just update the parameters and run the notebook again.

# %%
## Load the rent prices data
df_2_bed = pd.read_csv(Path('/kaggle/input/rent-data-statcan-1987-2020/Canada_2_Bed_rent.csv'), na_values='F')
df_3_bed = pd.read_csv(Path('/kaggle/input/rent-data-statcan-1987-2020/Canada_3_Bed_rent.csv'), na_values='F')
df_1_bed = pd.read_csv(Path('/kaggle/input/rent-data-statcan-1987-2020/Canada_1Bed_rent.csv'), na_values='F')
df_bachelor = pd.read_csv(Path('/kaggle/input/rent-data-statcan-1987-2020/Canada_bachelor_rent.csv'), na_values='F')

# %%
df_2_bed.head()
# Out:
#             City                    Province 1987 1988 1989 1990 1991 1992  \
# 0     St. John's   Newfoundland and Labrador  538  516  535  544  570  575
# 1  Charlottetown        Prince Edward Island  448  457  472  492  514  519
# 2    Cape Breton                 Nova Scotia  401  401  424  427  465  474
# 3        Halifax                 Nova Scotia  527  537  551  576  604  602
# 4    Campbellton          New Brunswick part  NaN  NaN  NaN  413  432  434
#
#   1993 1994  ...   2011   2012   2013    2014    2015    2016    2017    2018  \
# 0  562  566  ...  779.0  803.0  871.0   897.0   935.0   986.0   963.0   991.0
# 1  528  529  ...  764.0  808.0  808.0   840.0   832.0   876.0   901.0   922.0
# 2  474  487  ...  736.0  757.0  760.0   790.0   781.0   774.0   795.0   815.0
# 3  611  616  ...  932.0  960.0  984.0  1013.0  1056.0  1072.0  1115.0  1162.0
# 4  443  442  ...  573.0  582.0  583.0   594.0   598.0   608.0   614.0   631.0
#
#      2019    2020
# 0   980.0   997.0
# 1   936.0   983.0
# 2   847.0   826.0
# 3  1209.0  1264.0
# 4   639.0   633.0
#
# [5 rows x 36 columns]

# %%
def applyrangeandmelt(df, st_year, en_year, col_name):
    col_range = list(range(df.columns.get_loc(st_year),df.columns.get_loc(en_year)+1))
    sz = len(col_range)
    col_range.extend([0,1])
    df2 = df.iloc[: , col_range].copy()
    df3 = pd.melt(df2, id_vars=['City', 'Province'], value_vars=df2.columns[0:sz], var_name='Year', value_name=col_name)
    return df3

# %%
updated_df_2_bed = applyrangeandmelt(df_2_bed, '2010', '2020', '2-Bed ($)')
updated_df_3_bed = applyrangeandmelt(df_3_bed, '2010', '2020', '3-Bed ($)')
updated_df_1_bed = applyrangeandmelt(df_1_bed, '2010', '2020', '1-Bed ($)')
updated_df_bachl = applyrangeandmelt(df_bachelor, '2010', '2020', 'bachelor ($)')

# %%
updated_df_2_bed.head()
# Out:
#             City                    Province  Year  2-Bed ($)
# 0     St. John's   Newfoundland and Labrador  2010      734.0
# 1  Charlottetown        Prince Edward Island  2010      733.0
# 2    Cape Breton                 Nova Scotia  2010      691.0
# 3        Halifax                 Nova Scotia  2010      898.0
# 4    Campbellton          New Brunswick part  2010      559.0

# %%
updated_df_3_bed.head()
# Out:
#             City                    Province  Year  3-Bed ($)
# 0     St. John's   Newfoundland and Labrador  2010      762.0
# 1  Charlottetown        Prince Edward Island  2010      827.0
# 2    Cape Breton                 Nova Scotia  2010      953.0
# 3        Halifax                 Nova Scotia  2010     1124.0
# 4    Campbellton          New Brunswick part  2010      567.0

# %%
updated_df_1_bed.head()
# Out:
#             City                    Province  Year  1-Bed ($)
# 0     St. John's   Newfoundland and Labrador  2010      656.0
# 1  Charlottetown        Prince Edward Island  2010      582.0
# 2    Cape Breton                 Nova Scotia  2010      553.0
# 3        Halifax                 Nova Scotia  2010      737.0
# 4    Campbellton          New Brunswick part  2010      443.0

# %%
updated_df_bachl.head()
# Out:
#             City                    Province  Year  bachelor ($)
# 0     St. John's   Newfoundland and Labrador  2010         575.0
# 1  Charlottetown        Prince Edward Island  2010         483.0
# 2    Cape Breton                 Nova Scotia  2010         476.0
# 3        Halifax                 Nova Scotia  2010         641.0
# 4    Campbellton          New Brunswick part  2010         415.0

# %%
combined_df = updated_df_1_bed.copy()
combined_df['2-Bed($)'] = updated_df_2_bed.iloc[:,3]
combined_df['3-Bed($)'] = updated_df_3_bed.iloc[:,3]
combined_df['Bachelor($)'] = updated_df_bachl.iloc[:,3]
combined_df.rename(columns={'1-Bed ($)': '1-Bed($)'}, inplace=True)

# %%
combined_df.head()
# Out:
#             City                    Province  Year  1-Bed($)  2-Bed($)  \
# 0     St. John's   Newfoundland and Labrador  2010     656.0     734.0
# 1  Charlottetown        Prince Edward Island  2010     582.0     733.0
# 2    Cape Breton                 Nova Scotia  2010     553.0     691.0
# 3        Halifax                 Nova Scotia  2010     737.0     898.0
# 4    Campbellton          New Brunswick part  2010     443.0     559.0
#
#    3-Bed($)  Bachelor($)
# 0     762.0        575.0
# 1     827.0        483.0
# 2     953.0        476.0
# 3    1124.0        641.0
# 4     567.0        415.0

# %%
combined_df.shape
# Out:
# (671, 7)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         671 non-null    object
#  1   Province     671 non-null    object
#  2   Year         671 non-null    object
#  3   1-Bed($)     651 non-null    float64
#  4   2-Bed($)     653 non-null    float64
#  5   3-Bed($)     633 non-null    float64
#  6   Bachelor($)  637 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 36.8+ KB

# %%
combined_df.to_csv('rental_prices_mop_statcan_2010_2020.csv')

# %% [markdown]
# References:
#
# https://rentals.ca/blog/rental-guides - Data scraped from the rental reports from this location. Only the summary table is reproduced for this notebook. Dates are from August 2021 to Jun 2022.
#
# https://themeasureofaplan.com/rent-prices-versus-income/ - The second output csv uses the rental prices data that is used for analysis here.
